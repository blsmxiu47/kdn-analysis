# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#The-Data" data-toc-modified-id="The-Data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>The Data</a></span><ul class="toc-item"><li><span><a href="#SQLAlchemy-Pull" data-toc-modified-id="SQLAlchemy-Pull-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>SQLAlchemy Pull</a></span></li><li><span><a href="#Tweak-for-pandas" data-toc-modified-id="Tweak-for-pandas-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Tweak for pandas</a></span></li><li><span><a href="#EDA-First-Steps" data-toc-modified-id="EDA-First-Steps-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>EDA First Steps</a></span></li></ul></li><li><span><a href="#Variable-Preprocessing" data-toc-modified-id="Variable-Preprocessing-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Variable Preprocessing</a></span><ul class="toc-item"><li><span><a href="#Article-'tags'-preparation" data-toc-modified-id="Article-'tags'-preparation-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Article 'tags' preparation</a></span><ul class="toc-item"><li><span><a href="#Common-tags" data-toc-modified-id="Common-tags-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Common tags</a></span></li></ul></li><li><span><a href="#Text-Preparation-for-NLU---Article-Body" data-toc-modified-id="Text-Preparation-for-NLU---Article-Body-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Text Preparation for NLU - Article Body</a></span><ul class="toc-item"><li><span><a href="#Text-Cleaning" data-toc-modified-id="Text-Cleaning-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Text Cleaning</a></span></li><li><span><a href="#Lemmatization-(w/-POS-tagging)" data-toc-modified-id="Lemmatization-(w/-POS-tagging)-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Lemmatization (w/ POS tagging)</a></span></li><li><span><a href="#Token-Exploration" data-toc-modified-id="Token-Exploration-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Token Exploration</a></span></li></ul></li><li><span><a href="#Gensim-doc/token-prep" data-toc-modified-id="Gensim-doc/token-prep-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Gensim doc/token prep</a></span><ul class="toc-item"><li><span><a href="#ngrams---bigrams-&amp;-trigrams" data-toc-modified-id="ngrams---bigrams-&amp;-trigrams-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>ngrams - bigrams &amp; trigrams</a></span></li><li><span><a href="#Building-the-model" data-toc-modified-id="Building-the-model-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Building the model</a></span></li></ul></li></ul></li><li><span><a href="#Supervised-Topic-Modeling" data-toc-modified-id="Supervised-Topic-Modeling-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Supervised Topic Modeling</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#End-tags-predicting" data-toc-modified-id="End-tags-predicting-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>End tags predicting</a></span></li></ul></li></ul></li><li><span><a href="#Unsupervised-Topic-Modeling" data-toc-modified-id="Unsupervised-Topic-Modeling-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Unsupervised Topic Modeling</a></span><ul class="toc-item"><li><span><a href="#Topic-Modeling:-ngrams-TFIDF" data-toc-modified-id="Topic-Modeling:-ngrams-TFIDF-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Topic Modeling: ngrams-TFIDF</a></span></li><li><span><a href="#PLSA,-etc?" data-toc-modified-id="PLSA,-etc?-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>PLSA, etc?</a></span></li><li><span><a href="#Dynamic-Topic-Modeling" data-toc-modified-id="Dynamic-Topic-Modeling-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Dynamic Topic Modeling</a></span></li></ul></li></ul></div>

# %% [markdown]
# First let's go ahead and put the sqlalchemy for pulling data from psql just so we know where it's coming from

# %% [markdown]
# ## The Data

# %% [markdown]
# ### SQLAlchemy Pull

# %%
import numpy as np
import pandas as pd
from IPython.display import display, Math, Latex

# %%
# from pull_kdn_data.py
# Using sqlalchemy extract (all) data in from postgresql data table
#  'kdn_articles' and export to a format that we can use for cleaning
#  demos in python/pandas

# from sqlalchemy import create_engine, MetaData, Table, select

# engine = create_engine('postgresql://weswa:ringocat@localhost:5432/weswa')
# connection = engine.connect()
# meta = MetaData()
# meta.reflect(bind=engine)

# %%
# kdn_articles = Table('kdn_articles', meta, autoload=True, autoload_with=engine)

# stmt = select([kdn_articles])
# results = connection.execute(stmt).fetchall()
# kdn_articles_df = pd.DataFrame(
#     results, 
#     columns=['id', 'title', 'date_published', 'author', 'author_info', 
#         'tags', 'excerpt', 'post_text', 'url']
# )

# kdn_articles_df.to_csv('C:\\Users\\weswa\\psql_pulls\\20_03_kdnarticles.csv', 
#     sep=',', header=kdn_articles.columns,
#     index=False, encoding='utf-8')

# %% [markdown]
# ### Tweak for pandas

# %%
kdn_articles_df = pd.read_csv('C:\\Users\\weswa\\psql_pulls\\20_03_kdnarticles.csv')
kdn_articles_df.head()
# Out:
#    id                                              title date_published  \
# 0   1  What Data Scientists Can Learn From Qualitativ...     2016-07-14
# 1   2  Online Courses: Big Data Projects and Data Sci...     2016-07-14
# 2   3              2016 SIGKDD Service Award to Wei Wang     2016-07-14
# 3   4  Take a Risk Free Hadoop Ride. Save up to 80% c...     2016-07-14
# 4   5  Top KDnuggets tweets, Jul 6 – Jul 12: Statisti...     2016-07-13
#
#   author                   author_info  \
# 0     {}  By Alyona Medelyan, Thematic
# 1     {}                            {}
# 2     {}                     By SIGKDD
# 3     {}                    By Impetus
# 4     {}                            {}
#
#                                                 tags  \
# 0  Programming, Qualitative Analytics, Qualitativ...
# 1  Apache Spark, Big Data, Cassandra, Kafka, O'Re...
# 2                      ACM, Awards, SIGKDD, Wei Wang
# 3          Big Data, Data Warehouse, Hadoop, Impetus
# 4  Data Analysis, Jupyter, Pandas, Python, Statis...
#
#                                              excerpt  \
# 0  Learn what data scientists can learn from qual...
# 1  Check out these online courses from O'Reilly M...
# 2  Prof. Wei Wang wins ACM SIGKDD 2016 Service Aw...
# 3  The Impetus Data Warehouse Workload Migration ...
# 4  Statistical Data Analysis in #Python (#Jupyter...
#
#                                            post_text  \
# 0  comments\nBy Alyona Medelyan, Thematic.\nOpen-...
# 1  If you're working on a big data project or bui...
# 2  By SIGKDD.\nACM SIGKDD is pleased to announce ...
# 3  By Impetus\nAdvances in Open Source Hadoop dis...
# 4  Most popular \r\n@KDnuggets tweets for Jul 6 -...
#
#                                                  url
# 0  https://www.kdnuggets.com/2016/07/data-scienti...
# 1  https://www.kdnuggets.com/2016/07/oreilly-big-...
# 2  https://www.kdnuggets.com/2016/07/acm-sigkdd-2...
# 3  https://www.kdnuggets.com/2016/07/impetus-hado...
# 4  https://www.kdnuggets.com/2016/07/top-tweets-j...

# %%
articles = kdn_articles_df.sort_values(by=['date_published'])
articles.reset_index(drop=True, inplace=True)

# %%
articles.drop(columns=['id'], inplace=True)
articles.head()
# Out:
#                                                title date_published author  \
# 0                       Big Data Influencers Q4 2013     2013-10-05     {}
# 1  KPMG Capital Investment Fundfor Big Data and A...     2013-10-05     {}
# 2  Top news for Nov 3-9: 7 Steps for Learning Dat...     2013-10-05     {}
# 3  October Analytics, Big Data, Data Mining compa...     2013-10-05     {}
# 4  IEEE BigData 2013: Big Data challenges and pot...     2013-10-05     {}
#
#                           author_info tags  \
# 0    Gregory Piatetsky, Nov 15, 2013.  NaN
# 1                                  {}  NaN
# 2                                  {}  NaN
# 3  By Gregory Piatetsky, Nov 7, 2013.  NaN
# 4                                  {}  NaN
#
#                                              excerpt  \
# 0  Onalytica 2013 Q4 list of #BigData Influencers...
# 1  KPMG Capital will support technology partnersh...
# 2  7 Steps for Learning Data Mining and Data Scie...
# 3  The October 2013 acquisitions, startups, and c...
# 4  A report from inaugural IEEE Big Data conferen...
#
#                                            post_text  \
# 0  Gregory Piatetsky, Nov 15, 2013.\nOnalytica ha...
# 1  NEW YORK, Nov. 11, 2013 /PRNewswire/\nKPMG Int...
# 2  Most viewed news items\n\n\n 7 Steps for Learn...
# 3  By Gregory Piatetsky, Nov 7, 2013.\nHere is th...
# 4  Guest post by Anmol Rajpurohit, Oct 18, 2013.\...
#
#                                                  url
# 0  https://www.kdnuggets.com/2013/11/big-data-inf...
# 1  https://www.kdnuggets.com/2013/11/kpmg-capital...
# 2  https://www.kdnuggets.com/2013/11/top-news-wee...
# 3  https://www.kdnuggets.com/2013/11/october-anal...
# 4  https://www.kdnuggets.com/2013/10/ieee-bigdata...

# %%
articles.tail()
# Out:
#                                                   title date_published  \
# 9389                               ModelDB 2.0 is here!     2020-03-19
# 9390  24 Best (and Free) Books To Understand Machine...     2020-03-20
# 9391  Build an Artificial Neural Network From Scratc...     2020-03-20
# 9392  Top 20 ODSC 2020 Global Virtual Conference Ses...     2020-03-20
# 9393  Nine lessons learned during my first year as a...     2020-03-20
#
#                              author                    author_info  \
# 9389                             {}                             {}
# 9390  Reashikaa Verma, ParallelDots                          By ,
# 9391           Nagesh Singh Chauhan  By , Data Science Enthusiast.
# 9392                             {}                             {}
# 9393                 Jacob D Peters          By , Founder, Commsor
#
#                                            tags  \
# 9389  MLOps, ModelDB, Modeling, Version Control
# 9390        Books, Free ebook, Machine Learning
# 9391             Neural Networks, numpy, Python
# 9392                     ODSC, Online Education
# 9393             Advice, Career, Data Scientist
#
#                                                 excerpt  \
# 9389  We are excited to announce that ModelDB 2.0 is...
# 9390  We have compiled a list of some of the best (a...
# 9391  The second article in this series focuses on b...
# 9392  At ODSC 2020, we are unveiling our first ever ...
# 9393  What is it like to be a Data Scientist? There ...
#
#                                               post_text  \
# 9389  Sponsored Post.\n\nSince we wrote ModelDB 1.0,...
# 9390  comments\nBy Reashikaa Verma, ParallelDots\n“W...
# 9391  By Nagesh Singh Chauhan, Data Science Enthusia...
# 9392  Sponsored Post.\n\n\nConferences are an import...
# 9393  comments\nBy Jacob D Peters, Founder, Commsor....
#
#                                                     url
# 9389  https://www.kdnuggets.com/2020/03/verta-modeld...
# 9390  https://www.kdnuggets.com/2020/03/24-best-free...
# 9391  https://www.kdnuggets.com/2020/03/build-artifi...
# 9392  https://www.kdnuggets.com/2020/03/odsc-2020-gl...
# 9393  https://www.kdnuggets.com/2020/03/nine-lessons...

# %% [markdown]
# ### EDA First Steps

# %%
articles.describe()
# Out:
#                                                     title date_published  \
# count                                                9394           9394
# unique                                               9394           1955
# top     What is an Ontology? The simplest definition y...     2013-12-21
# freq                                                    1             59
#
#        author author_info         tags  \
# count    9394        9394         9051
# unique   1270        1940         8094
# top        {}          {}  Top stories
# freq     5555        4964          326
#
#                                                   excerpt  \
# count                                                9394
# unique                                               9254
# top     Seeking industry leaders in Business Translati...
# freq                                                    7
#
#                                                 post_text  \
# count                                                9393
# unique                                               9332
# top     PREDICTIVE ANALYTICS & DATA MINING\r\nTime to ...
# freq                                                    6
#
#                                                       url
# count                                                9394
# unique                                               9394
# top     https://www.kdnuggets.com/2014/11/top-news-201...
# freq                                                    1

# %%
articles['post_text'] = articles['post_text'].astype('str')

# %% [markdown]
# Note that there are duplicates of the excerpts and more significantly post_text. These are probably some regularly posted types like job openings.
#
# We did ensure not to include duplicates of title when we scraped the data.
#
# There aren't so many unique authors but that's because over half of the articles didn't have a clear author or else it was not scraped correctly. It really doesn't matter seeing as I don't especially care about the author for this module.
#
# urls are all unique, that's a good sanity check.
#
# Most of the tag combinations form a unique set, which means we'll probably be dropping and merging a great many tags (e.g. 'ML' and 'Machine Learning').

# %%
print('Mean length of excerpt:')
print(int(np.round(articles['excerpt'].apply(lambda x: len(x)).mean())), 'characters.')
# Out:
# Mean length of excerpt:
# 197 characters.

# %%
print('Mean length of raw post_text (including html characters, js, etc.):')
print(int(np.round(articles['post_text'].apply(lambda x: len(x)).mean())), 'characters.')
# Out:
# Mean length of raw post_text (including html characters, js, etc.):
# 4883 characters.

# %%
articles['post_text'][1]
# Out:
# "NEW YORK, Nov. 11, 2013 /PRNewswire/\nKPMG International announced\nthe formation of KPMG Capital, a new investment fund created to accelerate innovation in data and analytics (D&A) that will help clients of member firms unlock tangible value of their 'big data'.\nKPMG Capital will support technology partnerships, strategic alliances and the recruitment of top talent to create new D&A solutions. With these capabilities, KPMG member firms will help clients solve critical business challenges in such areas as new revenue streams, risk management and cost optimization.\nThe use of D&A has become a critical business priority as companies try to derive value from the vast amounts of data now available to them.\n\nA new KPMG survey of business leaders from many of the world's leading companies found that while 69% see D&A as strategically important to their current growth plans, an overwhelming 96% believe their company is not currently using D&A effectively.\nAddressing business challenges: innovating through partnerships\nInvestment will be made in a number of critical business areas including\n\n enhancing business flexibility; \n finance; \n regulation and compliance; \n improving workforce productivity; and \n customer and revenue growth.\n\nKPMG Capital will work to develop solutions that will focus on growth sectors such as healthcare, financial services, energy and telecommunications. KPMG Capital will also aim to invest in, partner with, and acquire organizations that specialize in data and analytics tools and assets.\nRead more."

# %%
text_series = articles['post_text']
print(text_series[0])
# Out:
# Gregory Piatetsky, Nov 15, 2013.
# Onalytica has done an interesting analysis of Big Data influencers on Tweeter.
# They took the tweets for the last 6 months containing the hashtag #BigData and treated mentions of other tweeters as a link. This initial network was made up of about 150,000 nodes. After removing isolated components, they ranked the nodes by PageRank.
# The methodology is different from their previous Big Data ranking based on Betweenness Centrality. Onalytica says that Betweenness Centrality puts connectors higher, but they found that PageRank more effectively highlights the real influencers in the network.
# Of course, no two rankings will be exactly the same, so for comparison I also added Klout, which considers not only Tweeter, but also Facebook, LinkedIn and other networks. Here are the top 20 entries in Onalytica list.
#
#
# Onalytica
# Rank
# Name
# Twitter
# Twitter
# Followers
# Klout
#
#
# 1
# Kirk Borne
# @KirkDBorne
# 6,643
#  65
#
#
# 2
# James Kobielus
# @jameskobielus
# 10,624
#  55
#
#
# 3
# Timo Elliott
# @timoelliott
# 10,768
#  64
#
#
# 4
# Bernard Marr
# @BernardMarr
# 67,792
#  68
#
#
# 5
# Gregory Piatetsky
# @kdnuggets
# 14,395
#  67
#
#
# 6
# Thor Olavsrud
# @ThorOlavsrud
# 1,083
#  51
#
#
# 7
# Phil Simon
# @philsimon
# 3,908
#  64
#
#
# 8
# Brian Eastwood
# @Brian_Eastwood
# 2,420
#  60
#
#
# 9
# R Ray Wang
# @rwang0
# 41,075
#  70
#
#
# 10
# E.G.Nadhan
# @NadhanAtHP
# 621
#  52
#
#
# 11
# Mike Gualtieri
# @mgualtieri
# 37,263
#  59
#
#
# 12
# Steve Lucas
# @nstevenlucas
# 4,152
#  58
#
#
# 13
# Doug Laney
# @Doug_Laney
# 15,539
#  66
#
#
# 14
# Natasha Bishop
# @Natasha_D_G
# 1,526
#  62
#
#
# 15
# Doug Henschen
# @DHenschen
# 3,078
#  60
#
#
# 16
# Michael Cavaretta
# @mjcavaretta
# 2,040
#  56
#
#
# 17
# Kenneth Cukier
# @kncukier
# 3,548
#  56
#
#
# 18
# V Mayer-Schonberger
# @Viktor_MS
# 1,095
#  51
#
#
# 19
# Joab Jackson
# @Joab_Jackson
# 4,418
#  57
#
#
# 20
# Sharon Machlis
# @sharon000
# 2,024
#  60
#
#
# For comparison, here are
# Klout Top Big Data Influencers, as of Nov 15, 2013.
# We only see one name in common between Onalytica and Klout lists, which I am pleased to note is @kdnuggets.
# The chart below shows there is no correlation between Onalytica rank and Klout.
# Here is Onalytica full list of 200 top Big Data influencers.

# %%
# text_series = [str(i) for i in text_series]
types = list(map(lambda x: type(x), text_series))
is_str = [1 if t==str else 0 for t in types]
print(np.mean(is_str))
# Out:
# 1.0

# %%
#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = "all"

# %%
# Let's explore the tags real quick
tags = articles['tags']
set(tags)
# Out:
# {nan,
#  'Analytics, Big Data, Machine Learning, Visualization, Washington-DC',
#  'Java, LIONbook, LIONoso, LIONsolver, Machine Learning, Optimization, Overfitting, Roberto Battiti, Yaser Abu-Mostafa',
#  'Decision Trees, Interpretability, Python, scikit-learn',
#  'Deep Learning, Multivariate Testing, Postdoc, Sweden, Umea University',
#  'Deep Learning, Gradient Descent, Machine Learning, Optimization, UAI',
#  'Francois Chollet, Machine Learning, Process, Workflow',
#  'Bayesian, Deep Learning, Hyperparameter, Machine Learning, Neural Networks, Optimization, Python, TensorFlow',
#  'Bayesian, Crowdsourcing',
#  'Data Science, Logistic Regression, Neural Networks',
#  'Capsule Networks, Geoff Hinton, Neural Networks, Research',
#  'Crime, Data journalism, Machine Learning',
#  'AI, Data Science, Machine Learning, Product',
#  'Amsterdam-Netherlands, Booking.com, Data Scientist',
#  'Amazon, BigML, Google, Louis Dorard, Machine Learning, PredicSis',
#  'Advice, Data Science, Data Science Education, Data Scientist',
#  'Advice, Data Scientist',
#  'Analytics, AZ, Business Strategy, CVS, Finance, Scottsdale',
#  'CloudStream, Data Scientist, Singapore',
#  'Advice, Analytics, Brad Klingenberg, Data Science, Fashion, Interview, Machine Learning, Stitch Fix, Trends',
#  'Geoff Hinton, Industries, Poll, Programming Languages',
#  'AI, Algorithms, Chatbot, Cheat Sheet, Machine Learning, Pandas',
#  'Social Analytics, Trends, Unstructured data',
#  'Climate Change, Competition, Mobility, Politics, United Nations',
#  'Bootcamp, Data Science, Pivigo',
#  'Kaggle, Machine Learning, OpenML, Ran Bi, Weka',
#  'Big Data, London, Michael Stonebraker, UK',
#  'Data Preparation, NLP, Sentiment Analysis, TF-IDF, Tokenization, Topic Modeling, Word Embeddings',
#  'API, GoodData, Open Analytics, Platform, San Francisco-CA',
#  'Berkeley-CA, Massive Datasets, MMDS, Workshop',
#  'Algorithms, Efficiency, Python',
#  'Advice, Career, Data Scientist, Hiring',
#  'Data Analytics, Healthcare, Minnetonka, MN, Telecommute, UnitedHealth Group',
#  'Career Advice, Churn, Data Preparation, Data Science, R',
#  'Deep Learning, PMML, TensorFlow',
#  'Data Science, Jobs, Vettery',
#  'Data Science, Machine Learning',
#  'Chubb, Insurance, Predictive Modeler, Warren-NJ',
#  'Data Science, Programming, Python',
#  'Chicago, IL, Manufacturing, PAW, Predictive Analytics World, Text Analytics',
#  'Metadata, Open Data',
#  'Business Analyst, Certificate, DE, U. Delaware, Wilmington',
#  'Bootcamp, CA, Global Big Data Conference, Santa Clara',
#  'Backpropagation, Denny Britz, Neural Networks, Python',
#  'App, Convolutional Neural Networks, Deep Learning, Flask, Movies, Sentiment Analysis',
#  'Austin-TX, iSchool, PhD position, University of Texas',
#  'Sentiment Analysis, Twitter',
#  'Algorithms, Big Data, Data Science, Python',
#  'AI, Algorithms, Big Data, Data Science, Deep Learning, Machine Learning, MIT, NLP, Reinforcement Learning, U. of Washington, UC Berkeley, Yandex',
#  'Advice, Challenges, eBay, Interview, Samaneh Moghaddam, Skills',
#  'Big Data, Experfy, Saama, Salesforce, Spotify, startups, Twitter, ZestFinance',
#  'Deep Learning, Geo-Localization, Google, Top tweets',
#  'Accenture, Analytics, Big Data, Hadoop, INFORMS, Intel, San Jose-CA, SAS',
#  'Business Analytics, Insurance, Manager, NE, South Sioux City',
#  'East Lansing-MI, Faculty, Machine Learning, Michigan State University, MSU',
#  '2017 Predictions, Bayesian, Cheat Sheet, Interview questions, Machine Learning',
#  'Advice, AstraZeneca, Bioinformatics, Career, Challenges, Healthcare, Interview, Xia Wang',
#  'MS in Analytics, Northwestern, Online Education, Predictive Analytics',
#  'Data Science, Domino, Explainable AI, Interpretability, Machine Learning, XAI',
#  'AI, Artificial Intelligence, Deep Learning, MIT, Reinforcement Learning, Self-Driving Car, UC Berkeley',
#  '2017 Predictions, Deep Learning, Machine Learning, Self-Driving Car',
#  'AI, Cloud, Hype, Mobile',
#  'Austin, Big Data, Data Science, TX',
#  'Bootcamp, Data Science Education, Hadoop, New York City, NY, Python, R, USA',
#  'Attivio, Business Intelligence, Data Silos, Forrester, Supply Chain',
#  'AutoML, Machine Learning, R2.ai, SaaS',
#  'Data Science, ebook, Privacy',
#  'Data Mining, Data Science Education, Mining Massive Datasets, Online Education, Stanford',
#  'KDD-2014, New York-NY, Workshops',
#  'BERT, NLP, Research, Transformer, ULMFiT',
#  'Boston, CA, Chicago, IL, London, MA, New York City, NY, San Francisco, UK',
#  'Erich Schubert, KDD-2014, Text Analytics, Trend Detection, Twitter',
#  'Influencers, Jeremy Howard, NLP, Rachel Thomas, Research, Richard Socher',
#  'Beer, Deep Learning, Generative Models, Recurrent Neural Networks, Zachary Lipton',
#  'Deep Learning, DeepMind, Neural Networks, Physics',
#  'Annandale, Data Analytics, ExxonMobil, Machine Learning, NJ, Oil & Gas, USA',
#  'fast.ai, Feature Engineering, Machine Learning, Pandas, Python, Time Series',
#  'Big Data, Big Data Strategy, Business Value, Monetizing, Russell Walker',
#  'Data Science, Deep Learning, New York-NY, NYU, Ran Bi, Yann LeCun',
#  'CA, Data Science, Hilary Mason, Marketing Analytics, San Francisco',
#  'Algorithms, Data Science, Data Scientist, Graph, Python',
#  'Data Workflow, Pipeline, Python, Workflow',
#  'Becker College, Data Science Education, Director, Worcester-MA',
#  'AI, Apache Spark, CA, Databricks, San Francisco',
#  'Deep Learning, Kaggle, Microsoft, Podcast, Ran Bi, Speech Recognition',
#  'Best Practices, Boston-MA, Chicago-IL, Data Mining, Elder Research, New York-NY, San Francisco-CA, SAS',
#  'Ajay Ohri, Fraud analytics, Ingo Mierswa, Open Source, RapidMiner',
#  'Google, NLP, Python, Speech Recognition',
#  'AI, Centrality, Dataiku, Trust',
#  'Big Data Hype, Deep Learning, Machine Learning, Skynet, Zachary Lipton',
#  'Data Analysis, Online Education, Python, TDWI',
#  'Facebook, Information Retrieval, Natural Language Processing, Neural Networks, NLP, Programming',
#  'Cross-validation, Machine Learning, Overfitting',
#  'Business Analytics, Data Science, Merrimack College, MS in Business Analytics, MS in Data Science, Online Education',
#  'Advice, Analytics, Data Science Skills, Data Scientist, Manager',
#  'Data Science, Faculty, MA, Worcester, WPI',
#  'Daniel D. Gutierrez, Hadoop, Jan Gelin, Rubicon Project, ZooKeeper',
#  'Data Scientist, New York-NY, Seattle-WA, Statistician, WhitePages',
#  '2017 Predictions, Big Data, Data Science, Healthcare, Predictions, Trends',
#  'Cheat Sheet, Coursera, Data Science Education, MS in Data Science, Python, Shakespeare',
#  'Big Data, Big Data Architect, Caserta, New York City, NY',
#  'Analytics, Australia, IAPA, Machine Learning, Melbourne',
#  'Australia, Clayton, Health, Lecturer, Monash University',
#  'Business Analytics, Cincinnati, Industry, OH',
#  'Nigeria, Open Data, Refugees',
#  'Axcess-Financial, Cincinnati, Data Governance, Manager, OH',
#  'Apple, CA, Cupertino, Data Scientist, Sensors',
#  'Artificial Intelligence, Data Mining, Data Science, Deep Learning, Explained, Machine Learning',
#  'Cheat Sheet, Pedro Domingos, Python vs R, Starbucks',
#  'Chess, Data Preparation, Python',
#  "Adversarial, AI, Architecture, GPU, O'Reilly, Privacy, San Francisco, TPU, Training Data",
#  'Analyst, Athens, Greece, SlashData, Telecommute',
#  'Climate Change, Competition',
#  'Amazon, Big Data, Databases, Matthew Mayo',
#  'Google, Machine Learning, Software Engineering, Technical Debt, Zachary Lipton',
#  'AI, Berlin, Enterprise, FutureText, H2O, Implementation, London, Online Education',
#  'Cheat Sheet, Programming, Python, Text Analytics',
#  'Big Data, Graphistry, Javascript, Leo Meyerovich, Motivation, Time Series, Trends, Visualization',
#  'Neural Networks, numpy, SQL, TensorFlow',
#  '2020 Predictions, Automated Data Science, AutoML, Cloud Computing, Data Science, NLP, Privacy, Security, Trends',
#  'AI, Australia, Lecturer, Melbourne, Monash University',
#  'Austin, Data Science, Director, RetailMeNot, TX',
#  'CA, Data Science, Dato, Pedro Domingos, San Francisco',
#  'AlphaGo, Machine Learning, Reddit, Self-Driving Car, TensorFlow',
#  'Data Mining, Postdoc, Sweden, Umeå, Umea University',
#  'Apple, Austin, Engineer, Project Manager, TX',
#  'AirBnB, Andrew Ng, Baidu, Deep Learning, Grant Marshall, Open Source, Reddit, Sentiment Analysis, Textbook',
#  'Business Analytics, China, London, MS in Business Analytics, New York City, NY, NYU, UK',
#  'Analytics, Employee Value, PAW, Predictive Analytics World',
#  'Best Practices, Big Data Analytics, Checklist, FICO',
#  'Apache Spark, Databricks, SQL',
#  'AI, Australia, Automation, Deep Learning, Enlitic, fast.ai, Healthcare, Jeremy Howard, Kaggle',
#  'Deep Learning, fast.ai, Jeremy Howard, Machine Learning, MOOC',
#  'Heriot-Watt University, PhD position, Scotland',
#  'AI, Francois Chollet, Research',
#  'Data Management, Data Platform, Hadoop, SVDS',
#  'Charity, Competition, DonorsChoose, Kaggle, KDD-2014, New York-NY',
#  'ActiveState, Keras, Machine Learning, Python, Statistics',
#  'GANs, Generative Adversarial Network, Neural Networks, Python',
#  'Berlin, Germany, Google, Microsoft, PAW, Predictive Analytics World',
#  'Alpine, Apache Spark, Hadoop, YARN',
#  'Data Scientist, Deep Learning, Hiring, Statistics',
#  'Analytically Speaking, JMP, Statistics',
#  'Analytics, BI, Data Democratization, Looker, Self-service',
#  'Data Preparation, Data Preprocessing, NLP, Text Mining',
#  'GitHub, Machine Learning, Research',
#  'Smartphone, Survey Analysis, Text Analytics',
#  'Book, Open Source, Optimization, Paulo Cortez, R, Springer',
#  'Data Preparation, Data Science, Data Visualization, Hiring, Jupyter, Machine Learning',
#  'Alibaba, Amazon, Bitcoin, Cartoon, Data Science, Skills',
#  'Analytics, CA, Data Science, Intuit, Manager, Mountain View',
#  'Apache Spark, Big Data, Kafka, Nandu Jayakumar, Relational Databases, Shark, Yahoo',
#  'Advanced Analytics, Gartner, Knime, Magic Quadrant',
#  '2016 Predictions, About Gregory Piatetsky, Bernard Marr, Big Data Influencers, import.io, Kirk D. Borne, Trends',
#  'Architecture, Bradenton, FL, Foot Locker',
#  'Data Science Education, Ingo Mierswa, RapidMiner',
#  'AI, Blockchain, Finance',
#  'Data Science, SQL',
#  'Big Data, Marketing, Research',
#  'Data Scientist, GitHub, Jupyter, Version Control',
#  'Acoustics, Deep Learning, Microsoft, Speech Recognition',
#  'Amazon Redshift, BigQuery, Pricing, Statsbot',
#  'Charlottesville, Faculty, HCI, Simulation, University of Virginia, VA',
#  'AI, Cloud Computing, Corinium, IBM, Las Vegas, NV, Security',
#  'Baidu, CA, Research Scientist, Sunnyvale',
#  'Data Science, Explained, Top tweets',
#  'AI, Biology, Challenge, Robots',
#  'Big Data, DC, IEEE, Keynote Speech, Tutorials, Washington',
#  'Analytics, Cleveland, Lubrizol, OH, Statistician',
#  'Analytics, Chicago, Data Science, IL, TDWI, Training',
#  'Data Science, Faculty, Worcester-MA, WPI',
#  'Data Science, Data Visualization, Migration, Research',
#  'Boston, Data Science, India, MA, ODSC',
#  'Neural Networks, NLP, Word Embeddings, word2vec',
#  'Data Scientist, Machine Learning',
#  'Balancing Classes, Data Preparation, Machine Learning, Unbalanced',
#  'Belgium, Boston, Brussels, CA, Chicago, IL, London, MA, New York City, NY, San Diego, San Francisco, UK, USA',
#  'Advice, Analytics, Big Data, Career, Customer Analytics, Customer Value, Interview, Machine Learning, Pricing, Real-time',
#  'Apache Spark, NLP, Pipeline, Spark NLP',
#  'Caffe, CNTK, Deep Learning, GPU, Keras, Microsoft, MXNet, PyTorch, TensorFlow',
#  'Artificial Intelligence, Blacksburg-VA, Cybersecurity, Faculty, Software Engineering, Virginia Tech',
#  'Data Mining Training, Dimensionality Reduction, Ethics, Youtube',
#  'Burtch Works, Python, R, SAS, Survey',
#  'Cambia Health Solutions, Data Engineer, Data Scientist, OR, Portland, Seattle, WA',
#  'CA, Data Science Education, Logit Academy, Los Angeles',
#  'Architecture, Art.com, Avro, Hadoop, HBase, Interview, Semantic Analysis, Solr, Thanigai Vellore',
#  'Business, Enterprise, Web Scraping',
#  'Director, New York-NY, Ontotext, RDF, Semantic Analysis, Unstructured data',
#  'Analytics, Big Data, Business Analytics',
#  'Airlines, Big Data',
#  'Data Science, Python, Web Scraping',
#  'Machine Learning, Redwood City-CA, Research Scientist, Rocket Fuel',
#  'American Family Insurance, Director, Insurance, Madison, Research, WI',
#  'Amazon Redshift, Hadoop, Looker, MPP Database, SQL',
#  'CA, Quantcast, San Francisco, Scientist',
#  'Big Data, Maps, Monetizing, Russell Walker, Zillow',
#  'Amherst, MA, Massachusetts, UMass',
#  'Deep Learning, Germany, Munich, PAW, Predictive Analytics World',
#  "ebook, Explainability, H2O, Interpretability, O'Reilly, Prediction, Trust",
#  'Analytics, Business Analytics, SQL, Statsbot',
#  'Algorithms, Machine Learning, Quantum Computing',
#  'CRISP-DM, Data Science, Methodology, Springboard',
#  'ActiveState, Data Science, Machine Learning, Python, White Paper',
#  'Augmented Reality, Aviation, Boeing, Data Visualization, David Kasik, Graphics, Interview, Visual Analytics',
#  'Cleveland, New York Community Bank, OH, Predictive Modeler, Risk Modeling, USA',
#  'Architecture, Deep Learning, Hyperparameter, Neural Networks',
#  '2019 Predictions, AI, Ajit Jaokar, Andriy Burkov, Anima Anandkumar, Brandon Rohrer, Daniel Tunkelang, Machine Learning, Pedro Domingos, Rachel Thomas, Zachary Lipton',
#  'Machine Learning',
#  'ActiveState, Deployment, Interview, Machine Learning',
#  'Image Classification, Image Recognition, Python, Segmentation',
#  'Awards, ICDM, IEEE, Rao Kotagiri',
#  'Advice, Career, Data Analytics, Hiring',
#  'Analytics, Burtch Works, Data Scientist, Hiring',
#  'Cambridge, Computer Vision, FeatureX, MA, Research Scientist',
#  'Amazon, Bangalore-India, Machine Learning Scientist',
#  'Bart Baesens, Business Analytics, Descriptive Analytics, Online Education, Predictive Analytics, Profit',
#  'Career Advice, Data Science, Data Science Team',
#  'Australia, Canberra, IAPA, Melbourne, Neural Networks, Patrick Hall, SAS, Sydney',
#  'Beginners, Data Preparation, NLP, Text Mining',
#  'Personalization, Segmentation',
#  'Bootcamp, Career, Cassandra, Data Analytics, DataStax, Global Big Data Conference, NoSQL',
#  'Automated, Data Science Platform, Machine Learning, Recommender Systems',
#  'Cancer Detection, Challenge, Image Recognition',
#  'Data Analytics, Doha, Machine Learning, Mohammed Zaki, Qatar, QCRI',
#  'Cambridge, Data Scientist, Forge.ai, MA, Machine Learning Engineer',
#  'Andrew Ng, Data Visualization, Donald Trump, R, Twitter, Word Cloud',
#  'Big Data, Internet of Things, IoT',
#  'AI, Automated Machine Learning, DataRobot, Machine Learning',
#  'Deep Learning, Online Games, Reinforcement Learning, Self-Driving Car',
#  'BERT, NLP, Performance',
#  'Data Science, Deep Learning, fast.ai, Google, Linear Algebra, Machine Learning, MIT, NLP, Reinforcement Learning, Stanford, Yandex',
#  'Pharma, Text Analytics',
#  'Data Science, PAW, Predictive Analytics World, Unicorn',
#  'Canada, Data Scientist',
#  'Business Intelligence, Certification, Data Science Certificate, Data Science Education, Online Education',
#  'Advanced Analytics, Clear Capital, Data Scientist, Director, NV, Reno',
#  'Deep Learning, Eigenface, Jurgen Schmidhuber, Machine Learning, Reddit, Tinder',
#  'Octoparse, Web Scraping',
#  'AI, CA, Deep Learning, RE.WORK, San Francisco',
#  'Balancing Classes, Deep Learning, Neural Networks, Training, Unbalanced',
#  'Apache Spark, Knime, Rosaria Silipo, Time Series',
#  'antivirus, AVAST, Machine Learning, Prague-CR',
#  'Big Data, Data Science, Predictive Modeling, RapidInsight',
#  'Analytics, Data Science Jargon, Sampling, Statistics, Variance',
#  'Chicago, IL, Manufacturing, PAW, Predictive Analytics World',
#  'Deep Learning, Geoff Hinton, Grant Marshall, Machine Learning, Podcast, Reddit',
#  'Data Scientist, Houston, TX, Waste Management',
#  'Experfy, LinkedIn, Machine Learning, Marketplace, Python, R',
#  'Machine Learning, Metrics, Python, ROC-AUC',
#  'Boosting, Gradient Boosting, Machine Learning, XGBoost',
#  'Cray, Data Scientist, New York-NY, YarcData',
#  'Convolutional Neural Networks, Deep Learning',
#  'Berlin, Developer, Germany, Pair Finance, Python',
#  'AI, DATAx, Marketing',
#  'Cloud, Data Science, Gradient Boosting, Interpretability, Machine Learning, Predictive Analytics, Python',
#  'Data Science, Tips',
#  'Business Analyst, Career, Data Analyst, Data Scientist, Hiring, Jigsaw Academy, Trends',
#  'Amazon, Apache, AWS, Cassandra, DynamoDB',
#  'Data Preparation, Missing Values, R',
#  'Deep Learning, Neural Networks, Yann LeCun',
#  'AI, Andrej Karpathy, CA, Databricks, Marc Andreessen, Matei Zaharia, San Francisco, Spark',
#  'Big Data, Data Science, Ethics, Hui Xiong',
#  'Apache Spark, Big Data, Hadoop, iDatalabs',
#  "Analytics Leader, Data Visualization, Interview, Michael O'Connell, Statistics, TIBCO",
#  'Data Cleaning, Data Preparation, Data Science, Machine Learning',
#  'IoT, Learning, Real-time',
#  'Darmstadt, Germany, Heidelberg',
#  'Donald Trump, OdinText, Survey, Text Analytics, Tom HC Anderson',
#  'Chicago-IL, Digital Analyst, IRI, New York-NY',
#  'Data Preparation, Data Preprocessing, NLP, Python',
#  'Advanced Analytics, Bart Baesens, Big Data, Online Education',
#  'Andrew Ng, CA, Deep Learning, Google, MetaMind, Quoc Le, RE.WORK, Richard Socher, San Francisco',
#  'Cognitive Mining, StatSoft, Thomas Hill',
#  'Data Science, Relational Databases, SQL',
#  'Big Data, BigQuery, GDELT, Google, Kalev Leetaru, Ran Bi',
#  'AIG, Director, Manager, Natural Language Processing, New York City, NY, Research Scientist',
#  'Advice, Andriy Burkov, Carla Gentry, Data Science Skills, Data Scientist',
#  'Generative Adversarial Network, Neural Networks, Training, Uber',
#  'Data Cleaning, Data Preparation',
#  'Big Data, Graph Analytics, Graph Mining, Hadoop',
#  'AI, Chatbot, Deep Learning, Machine Learning, Neural Networks, RE.WORK, Virtual Assistant',
#  'Data Mining Training, DC, Salford Systems, Washington',
#  'Computer Vision, DC, Washington',
#  'Data Science, Data Science Skills, Kaiser Fung, Self-Driving Car',
#  'AI, Big Data, Finance, Marketing, New York, NY, Pharma',
#  'Cognitive Computing, IIA, Machine Intelligence, Machine Learning, Tom Davenport',
#  'Data Science, Machine Learning, Programming Languages, Python, R, Scala',
#  'Architecture, Deep Learning, Feature Engineering, Neural Networks',
#  'Competition, Crowdsourcing, Data Science, DrivenData, Nonprofit, Social Good',
#  'AWS, Cloud Analytics, PaaS, RapidMiner',
#  'Computational Experiments, Stanford, Workbench',
#  'Cognitive Computing, GitHub, IBM, IoT, James Kobielus',
#  'AI, Bias, Failure, Machine Learning, Top tweets, Variance',
#  'Conal Sathi, Consumer Insights, Experimentation, Graph Analytics, Interview, Machine Learning',
#  'AI, Automated Machine Learning, AutoML, Gradient Boosting, Hyperparameter, NeurIPS',
#  'Dark Data, Excel, Surveys',
#  'Big Data Vendors, EMC, LinkedIn, startups, Timeline',
#  'Boston-MA, Chicago-IL, IE Group, INFORMS, Meetings, PAW',
#  'Certificate, Chicago, Data Models, IL, TDWI',
#  'Big Data Privacy, Brain, Data Science, Neural Networks, Programming Languages, Top tweets',
#  'Coursera, Johns Hopkins, Josh Wills, MADlib, Open Source',
#  'Active Learning, AWS, ebook, Figure Eight, Machine Learning',
#  'Analyst, Analytics Manager, Arlington Heights, Customer Analytics, Depew, HSBC, IL, NY',
#  'Analytics, Atlanta, CA, GA, Minneapolis, MN, Redwood City, Seattle, TDWI, Training, WA',
#  'Deep Learning, Image Recognition, ImageNet, Machine Learning, Neural Networks, Transfer Learning, Zachary Lipton',
#  'John Elder, London-UK, PAW, Predictive Analytics World',
#  'CHEMDNER, Cheminformatics, Competition, Information Retrieval, Patents, Text Mining',
#  'Dashboard, Data Visualization, JMP',
#  'Bellevue, Data Scientist, T-Mobile, WA',
#  'Advice, Career, Data Science, Interview',
#  'Certification, Data Analytics, Simplilearn',
#  'ADAPT Centre, Dublin, Ireland, Machine Learning Engineer, Manager, Trinity College Dublin',
#  'Director, Lecturer, Tacoma, U. of Washington, WA',
#  'AI, Data Science, Interview, Interview questions, Netflix',
#  'Book, Charu Aggarwal, Recommender Systems',
#  'Data Analysis, Measurement, RideOnData, Statistics',
#  'Big Data, Business Analytics, IE Group, Innovation, Las Vegas',
#  'CA, Economics, Faculty, Network Science, Santa Cruz, UCSC',
#  'Machine Learning, Myths, Pedro Domingos',
#  'Applications, Dublin, Ireland, Machine Learning, Predictive Analytics, Training',
#  'API, Research, Text Analytics, Text Mining, Webhose',
#  'Data Analysis, Data Exploration, Data Visualization, SVDS',
#  'Business Analytics, CA, Faculty, San Francisco, University of San Francisco',
#  'Cartoon, Coffee, Competition, Deep Learning',
#  'API, Clustering, Python, Text Analytics, Unstructured data',
#  'Facebook, Gartner, Graf.ly, IBM, Knime, RapidMiner, SAS, Yann LeCun',
#  'Data Analysis, Data Exploration, Data Preparation, Jupyter, Python, SVDS',
#  'Cartoon, Deep Learning, Humor, Machine Learning, Robots',
#  'AI, Canada, Data Science, Law, Machine Learning, Washington',
#  'Big Data, Boston, Data Visualization, IE Group, Internet of Things, MA, Summit',
#  'DevOps, GraphDB, Ontotext, SPARQL',
#  'Big Data, Bill Schmarzo, EMC, Internet of Things, IoT, Top bloggers',
#  'NLP, Speech Recognition',
#  'Data Lake, Data Warehouse, SAS, Tamara Dull',
#  'Algorithms, Andrew Ng, Data Visualization, Machine Learning, Python, TensorFlow, Top tweets',
#  'Apple, CA, Cupertino, Engineer, Manager, Software Engineer',
#  'CT, Faculty, Marketing, New Haven, Yale',
#  'Azure ML, Cloud Computing, Hadoop, Machine Learning, Marketplace, Microsoft Azure, Nate Silver, Predictive Analytics, Strata',
#  'Big Data, CleverTap, P-value, Probability, Sampling',
#  'Analytics, Burtch Works, Career, Hiring',
#  'Analytics, Business Intelligence, Chicago-IL, Conference, Data Processing, IE Group, Innovation, Visualization',
#  'Analytics, Business Intelligence, Chicago-IL, Conference, IE Group, Innovation',
#  'AR, Bentonville, Customer Analytics, Director, Walmart',
#  'Master of Science, MS in Analytics, Online Education, Penn State',
#  'Advice, Big Data, Data Science, Gary Shorter, Healthcare, Interview, Quintiles',
#  'Deep Learning, Europe, RE.WORK, Summit',
#  'NEC Labs, NJ, Princeton, Researcher',
#  'DBSCAN, Knime, Outliers, Python',
#  'BigQuery, GDELT, Google, New York City, Reddit',
#  'Data Science, Energy, Use Cases, Utilities',
#  'Finance, LSTM, Neural Networks, Recurrent Neural Networks, Statsbot',
#  'France, Germany, IBM, Research Positions, Switzerland, Yale',
#  'Clustering, Humor, Machine Learning, Recurrent Neural Networks, Reddit',
#  'CA, Data Scientist, eBay, San Jose',
#  'Business Analytics, Faculty, IA, Iowa City, University of Iowa',
#  'Barcelona, Big Data, Data Visualization, Enterprise, Europe, Innovation, London, Machine Learning, Spain, UK',
#  'Adversarial, AI, GANs, Generative Adversarial Network, Machine Learning',
#  'Array database, Michael Stonebraker, Python, R, SciDB, Webcast',
#  'Book, Eric Siegel, Explained, Key Terms, Predictive Analytics',
#  'AI, CA, Developers, Machine Learning, San Francisco, Software',
#  'Optimization, Predictive Analytics, Product Analytics, Risk Analytics, Use Cases',
#  'A/B Testing, Econometrics, Regression, Statistics',
#  'AI, Deep Learning, Fei-Fei Li',
#  'Data Science Education, GitHub, New York City, NY, Python, USA',
#  'Andrew Ng, Coursera, Free ebook, Machine Learning, Microsoft Research, Reddit',
#  'Eric Siegel, Finance, Government, Healthcare, Manufacturing, Marketing, PAW, Predictive Analytics World, Workforce Analytics',
#  'AI, Analytics, Boston, Deep Learning, Las Vegas, London, Meetings, New York City, San Francisco',
#  'CO, Computational Statistics, Golden, NREL, Renewable Energy, Scientist',
#  'Communication, Data Science Team, Startup',
#  'Data Science Certificate, Data Science Education, Online Education, Statistics.com',
#  'CA, Greta Roberts, PAW, Predictive Analytics World, San Francisco, Workforce Analytics',
#  'Asia, Dataset, Europe, Largest, Poll, USA',
#  'Data Scientist, DC, FiscalNote, New York City, NY, Washington',
#  'Data Science, Fake News, Machine Learning, Naive Bayes, Politics, Text Analytics',
#  'Analytics Engine, Challenge, Halloween, Lavastorm',
#  'Business Analytics, Data Science, Faculty, Hoboken-NJ, Stevens',
#  'About KDnuggets, Cartoon, France, Self-Driving Car',
#  'Ensemble Methods, Hyperparameter, Neural Networks, Overfitting, Tips',
#  'CA, H2O, Hilary Mason, Machine Learning, Mountain View, Robert Tibshirani',
#  'Credit Risk, Hamburg-Germany',
#  'Adversarial, Convolutional Neural Networks, Deep Learning, Google, Matthew Mayo, Reddit, TensorFlow',
#  'AI, NLP, Text Analytics',
#  'Beginners, Clustering, K-means',
#  'Big Data, MLlib, Poll, Strata',
#  'Apple, CA, Cupertino, Data Science, Maps, Software Engineer',
#  'Apache Spark, Databricks, Free ebook, Python, Scala, SQL',
#  'Deep Learning, Top bloggers',
#  'Machine Learning, Modeling, WhitePages',
#  'CrowdFlower, Data Democratization, Data Science, Infographic, Predictions for 2015, Social Good, Trends',
#  'API, Convolutional Neural Networks, Dropout, Flask, Neural Networks, Python, RESTful API, TensorFlow',
#  'Deep Learning, Google, Image Recognition, Jeff Hammerbacher, Matthew Mayo, NIPS, TensorFlow',
#  'Deep Learning, SlideShare, Top stories, Watson',
#  'Cheat Sheet, Data Science, Django, Hadoop, Java, Machine Learning, MATLAB, Python, R',
#  'Data Science, Poll, Skills, Team',
#  'AI, Data Science, Machine Learning',
#  'Ensemble Methods, Gradient Boosting, Python',
#  'AI, Automation, Poll, Social Good',
#  'AI, Analytics, DataRobot, Jen Underwood',
#  '2020 Predictions, AI, AutoML, Baidu, Blockchain, IoT, NLP, Quantum Computing, Research',
#  'Chennai-India, Crayon Data, Flutura, India, Kolkata-India, startups',
#  'Algorithms, Carlos Sarraute, Communication, Data Mining, Phone Usage',
#  'AI, Charu Aggarwal, Deep Learning, Python, Recommender Systems, Top tweets',
#  'Data Science, Data Scientist, DJ Patil, Online Education, R, Videolectures, Youtube',
#  'Analytics, Certificate, MOOC, Online Education, Peter Bruce, Predictions, Statisticians, Statistics.com',
#  'Analytics, Gartner, Optimization, Skills',
#  'AI, Backpropagation, Bias, Capsule Networks, Data Science Tools, Geoff Hinton, Regression, Top tweets',
#  'Big Data, Data Cleaning, Data Preparation, Data-Driven Business',
#  'Business Value, Data Visualization, Lift charts, Predictive Models, Python, R',
#  'Computer Vision, Convolutional Neural Networks, Deep Learning, Image Recognition, Neural Networks',
#  'Big Data, Business Value, Conference, INFORMS, San Jose-CA',
#  'Data Cleaning, Flink, Neural Networks, R, Survival Analysis',
#  'AspenTech, Bedford, Data Scientist, MA, Manufacturing',
#  'Machine Learning, Statistics',
#  'AI, Hype, Logistic Regression, Machine Learning, Modeling, Python, Skills, Workflow',
#  'Challenge, Competition, Innocentive, Medical Applications, Prediction',
#  'Analytics, Boulder-CO, Business, Leeds',
#  'Cross-validation, Modeling, Overfitting, Validation',
#  'Big Data Strategy, KPI, startups',
#  'Correlation, Dancing, Statistics',
#  'Berkeley, CA, Cogitativo, Data Scientist, Healthcare',
#  'Alexandria, Data Scientist, Institute for Defense Analyses, Research Analyst, VA',
#  'Decision Making, Programming Languages, R',
#  'Postdoc, Research, Switzerland, University of Zurich, Zurich',
#  'Data Science Skills, Hadoop, Hadoop 2.0, Joel Horwitz, LinkedIn, Machine Learning, R',
#  'Dean Abbott, John Elder, London, PAW, Predictive Analytics World, UK, Usama Fayyad',
#  'Beer, Data Curation, Dataset, Python',
#  'Advice, Big Data, Elephant Scale, Hadoop, Hiring, Open Source, Sujee Maniyam, Trends',
#  'Ethics, Google, Machine Learning, Optimization, TensorFlow',
#  'Data Scientist, Logistic Regression, Machine Learning',
#  'Beer, Centrality, Distribution, Statistics',
#  'Analyst, Business Intelligence, Maryville University, MO, St. Louis',
#  'Data Science, Data Visualization, Generative Adversarial Network, Interview, Machine Learning, numpy, Python, Regression, Statistics',
#  'CRISP-DM, Data Mining, Tom Khabaza',
#  'Data Science, Manager, Visualization',
#  'Enterprise, free download, Predictive Analytics, SAP',
#  'Data Science, Data Visualization, Datadeck',
#  'BOXX, Caffe, Deep Learning, MXNet, PyTorch, TensorFlow',
#  'Football, Julia, Optimization, Python, R, Sports',
#  "Continuum Analytics, Data Scientist, Valentine's Day",
#  "AI, Artificial Intelligence, New York City, NY, O'Reilly",
#  'CA, PAW, Predictive Analytics World, San Francisco, Workforce Analytics',
#  'Data Engineer, Fraud analytics, Midigator, Stream Processing, Telecommute',
#  'Data Science Education, Meetings, Online Education, Text Analytics, Visual Analytics',
#  'CA, Finance, PAW, Predictive Analytics World, San Francisco',
#  'Applications, Computer Vision, InData Labs, Trends',
#  'Business Value, Facebook, Google, LinkedIn, Microsoft, Yahoo',
#  'Competition, Healthcare, MJFF',
#  'Applications, Banking, Consumer Analytics, Data Mining, Data Science, Healthcare, Industry, Poll',
#  'Autodesk, CA, Data Analyst, San Francisco',
#  'Classification, Clustering, Explained, Key Terms, Machine Learning, Regression, Support Vector Machines',
#  'Advice, Career, Data Science, Hiring, Jobs',
#  'Data Science, Lift charts, Metrics',
#  'Big Data, Hadoop, Jeff Kelly, Market Research, New York-NY, NoSQL, Wikibon',
#  'AI, AirBnB, Books, Machine Learning, Neural Networks, Python, Sebastian Raschka, Top tweets',
#  'RE.WORK, Unsupervised Learning',
#  'Austin, Chief Analytics Officer, Chief Data Officer, IQPC, TX',
#  'Big Data Analytics, Certification, Free ebook, Hadoop, Online Education, R, SAS, Simplilearn',
#  '2018 Predictions, AI, Machine Learning, Production',
#  'Amazon, Azure ML, Clarifai, Cloud Analytics, Economics, IBM Watson, MetaMind, Startup, Zachary Lipton',
#  'Dublin, Ireland, NoSQL',
#  'Analytics, Mathematics, Optimization, Python',
#  'AI, Healthcare, Humans vs Machines',
#  'AI, Data Science, India, London, ODSC, San Francisco, UK',
#  'AI, Climate Change, Speech Recognition, Statistical Learning, Top tweets',
#  'Automated Machine Learning, Automation, Data Science, Feature Engineering, Machine Learning',
#  'Flink, Python, Realtime Analytics, Streaming Analytics, Will McGinnis',
#  'Columbus, Cummins, Data Engineer, IN',
#  'Cost Function, Gradient Descent, Machine Learning, Sebastian Raschka',
#  'API, BigML, Machine Learning, Python',
#  'Apache Spark, Databricks, Graph Analytics',
#  'Booz Allen, Data Science Education, Metis, Online Education',
#  'Air traffic, Data Processing, Data Wrangling, Trifacta',
#  'Cybersecurity, Data Analytics, Hiring, Singapore',
#  'CA, Intern, Quantcast, San Francisco, USA',
#  'Advice, Business, Data Scientist, Machine Learning, ROI',
#  'Data Processing, Programming, Python, Text Analytics',
#  'AL, Boeing, Data Architect, Huntsville, Technologist',
#  'Computer Vision, Deep Learning, Machine Intelligence, MIT, Prediction, RE.WORK',
#  'Big Data, Deep Learning, Face Recognition, Google, Open Source, Reproducibility, Tensor, Use Cases',
#  'Customer Analytics, New York-NY, Wilmington-DE',
#  'Gephi, Graph Visualization, Linkurious, Neo4j, Packt Publishing, Python, StackOverflow',
#  'JMP, Kaiser Fung, Market Research, Rob Reul',
#  'Deep Learning, language, Malta, Summer School, Vision',
#  'Book, Business Intelligence, Decision Making, Text Mining, Tom Davenport',
#  'Analytics Leader, Houston-TX, Schlumberger',
#  'Image Recognition, Object Detection, YOLO',
#  'Data Analytics, Jer Thorp, Las Vegas-NV',
#  'Alteryx, Anaconda, Angoss, Data Science Platform, Domino, Gartner, H2O, IBM, Knime, Machine Learning, Magic Quadrant, RapidMiner, SAS',
#  'Big Data, Meetup, Online Games',
#  'AI, CA, Deep Learning, Machine Learning, RE.WORK, San Francisco',
#  'Analytics, CAP, Certification, INFORMS',
#  'Hitachi, Infosys, Kaggle, Palantir, Pentaho, RapidMiner, startups',
#  'Data Science, Drew Conway, Venn Diagram',
#  'Chubb, Customer Experience, Manager, Marketing Analytics, New York City, NJ, NY, PA, Philadelphia, Whitehouse Station',
#  'Apache Spark, Databricks, Matei Zaharia, Open Source, Tungsten',
#  '2017 Predictions, Deep Learning, IBM, IBM Watson, TensorFlow',
#  'Cloudera, Deep Learning',
#  'Data Scientist, G Research, London, UK',
#  'Accuracy, Advice, Lucidworks, Scalability, Search, Search Engine',
#  'AI, AlphaGo, Games, Monte Carlo Tree Search',
#  'Data Scientist, Swisscom, Switzerland',
#  'Cambridge, Data Preparation, MA, Pharma, Procurement, Tamr',
#  'Classification, Data Classification, Regression, Similarity',
#  'Big Data Software, Education, LinkedIn, Monetizing, Products',
#  'Data Science, Internet of Things, IoT, London, Online Education',
#  'AI, Cloud Computing, Coursera, Google, Google Cloud, Machine Learning, TensorFlow',
#  'Australia, Blockchain, Lecturer, Melbourne, Monash University',
#  'Harrisburg, Harrisburg University, PA, Unstructured data',
#  'Bellevue, Bing, Microsoft, Software Engineer, WA',
#  'Business, Data Scientist, Hiring, Salary',
#  'DataKind, Microsoft, New York City, Seattle, Social Good, Traffic',
#  'Bayes Theorem, Machine Learning, Naive Bayes, Probability',
#  'Deep Learning, Explained, Neural Networks',
#  'Accenture, Apache Spark, Chicago-IL, Hadoop, MIT, Online Education, Stanford, Student Competition',
#  'Attention, Deep Learning, NLP, Transformer',
#  'Ensemble Methods, Kaggle, R, Recurrent Neural Networks, Tutorials',
#  'Datasets, Reproducibility, Research',
#  'Automation, Process, White Paper',
#  'Employee Churn, Employee Value, GitHub, Pasha Roberts, R, Talent Analytics',
#  'Data Preparation, Data Science, Deep Learning, Machine Learning, NoSQL, Python, SQL',
#  'Challenges, eBay, LDA, Samaneh Moghaddam, Sentiment Analysis, Text Mining',
#  'Advice, Big Data, Deep Learning, GPU, NVIDIA',
#  '24houranswers, Analytics, Data Science, Education, Mathematics, Statistics, Telecommute',
#  'Advice, Blockchain, Data Scientist, Hiring, Machine Learning, Poll',
#  'Beer, Data Curation, Dataset, Python, Web Scraping',
#  'AI, Explainable AI, Explanation, Interpretability, Machine Learning, Trust',
#  'Biologics, BMS, Bristol-Myers Squibb, Quality Control',
#  'Data Engineering, Data Science, Developers, DevOps, Software Engineering',
#  'Great West Casualty Company, Insurance, Manager, NE, South Sioux City',
#  'Data Science, Products, Sean McClure',
#  'Data Mining Software, Hadoop, Poll, R, RapidMiner',
#  'JMP, Lavastorm, NoSQL, Ontotext, Talend',
#  'Algorithms, Andrew Ng, Bias, Machine Learning',
#  'Analytics, Customer Analytics, Fashion',
#  'Advice, Data Science, DataCamp, iDatalabs, Kaggle',
#  'Apache Spark, Deep Learning, Google, Image Recognition, Programming Languages, Salary',
#  'Complexity, Deep Learning, Model Performance, Regularization',
#  'Data Science, Manager, Telecommute, UnitedHealth Group',
#  'Applied Statistics, Richmond, Statistician, VA',
#  'Certification, Hadoop, R, Simplilearn',
#  'Boston, CA, Data Scientist, MA, Pear Therapeutics, San Francisco',
#  'Certificate, Data Science Certificate, Data Science Education, MS in Analytics, MS in Data Science, Online Education',
#  'AGI, AI, AlphaGo, DeepMind, Machine Learning, Neuroscience, Reinforcement Learning, Rich Sutton, Yann LeCun',
#  'Customer Analytics, Lifetime Value, SQL, Statsbot',
#  'CA, Data Science, Hadoop, IE Group, San Diego, Summit, USA',
#  'Artificial Intelligence, Deep Learning, Emotion',
#  'Noise, Regression, Statistics, Time Series',
#  'Cartoon, Football, Soccer, World Cup',
#  'Analytics, Data Science, Database, IBM, Real-time',
#  'Azure ML, Deep Learning, DJ Patil, Hilary Mason, IPython, Machine Learning, Marketplace, Python, R',
#  'Austin, Python, Scientific Computing, SciPy, Sebastian Raschka, TX',
#  'Data Mining Software, Poll',
#  'GitHub, Machine Learning, Open Source, Python, scikit-learn',
#  'Automated Machine Learning, AutoML, Machine Learning, Poll',
#  'Dashboard, Data Visualization, Maptive',
#  'Causation, Correlation, Feature Engineering, High-dimensional, Machine Learning, Overfitting, Pedro Domingos',
#  'Canada, Data Science, DevOps, Montreal, R2',
#  'Computer Vision, Deep Learning, Neural Networks, Video recognition',
#  'ACI Worldwide, Analytics Expert, Digital Payments, FL, Naples',
#  'Analyst, Atlanta, Data Scientist, GA, Operations Research, Turner',
#  'Analytics, Data Science, TDWI, Workshops',
#  'Cologne, Data Scientist, Germany, Saloodo!',
#  'Bonn, Budapest, CA, China, Helsinki, Porto, Research Positions, San Diego, WI',
#  'Algorithms, Clustering, Dataset, K-means',
#  'Delft, Machine Learning, Netherlands',
#  'Automated, Automated Data Science, Competition, Data Science',
#  'Albuquerque, Data Scientist, NM, RS21',
#  'Complex Systems, Crowdfunding, Shaun Swanson, Thermostatistics',
#  'Apache Spark, Developers, Global Big Data Conference, Hadoop, Highlights, Security, Spark SQL',
#  'Career Advice, Data Science, Interview',
#  'Data Visualization, Top tweets',
#  'Deep Learning, Machine Learning, Neural Networks, Reinforcement Learning',
#  'API, Explained, Flink, Graph Mining, Machine Learning, Streaming Analytics',
#  'Germany, Munich, PAW, Predictive Analytics World',
#  'Data Mining Books, Deep Learning, Free ebook, Hadoop, SQL',
#  'Data Preparation, Data Processing, Jeopardy, Trifacta',
#  'Apache Spark, Data Mining Software, Excel, Hadoop, Knime, Poll, Python, R, RapidMiner, SQL',
#  'Autoencoder, Deep Learning, Machine Learning, MNIST, TensorFlow',
#  'CA, Data Scientist, Pear Therapeutics, San Francisco',
#  'Data Scientist, Healthcare, New York, NY',
#  'Greta Roberts, Implementation, Predictive Analytics, Project Fail',
#  'Online Education, Predictive Analytics, The Modeling Agency, TMA, Washington',
#  'Anaconda, Deployment, Machine Learning, Scalability',
#  'Data Scientist, Nike, Portland-OR',
#  'Dark Data, Data Preparation, Pneuron, Tom Fountain',
#  'Competition, Data blending, Data Science, Kaggle, Netflix',
#  'Analytics, Business Intelligence, Data Science, Online Education, TDWI, Training',
#  'Data Engineering, Germany, Hamburg, Jimdo, Manager',
#  'Data Science, MS in Data Science, Northwestern, Online Education',
#  'AI, Data Science, Data Scientist, UI/UX',
#  'Cloudera, Data Wrangling, Hadoop, Kafka, Trifacta',
#  'Computer Vision, K-means, Mathematics, PyCharm, SQL',
#  'Gary Marcus, Google Trends, Java, Python, R, StackOverflow',
#  'Beginners, Book, Linear Algebra, Machine Learning, Mathematics, Richard Han',
#  'AI, Crime, Finance',
#  'Game Theory',
#  'Data Science Education, NeurIPS, Top tweets',
#  'Internet of Things, IoT, Sensors',
#  'AI, Artificial Intelligence',
#  'Chicago, IL, PAW, Predictive Analytics, Predictive Analytics World',
#  'Data Science, Jupyter, Python, SVDS',
#  'Business Analytics, Career, Data Science, Kaiser Fung, New York City, NY, NYU',
#  'Boston, CA, Chicago, France, IL, London, MA, San Francisco, UK, USA',
#  'edX, Harvard, Programming, Statistics.com',
#  'Analysis, Analytics, R',
#  'Big Data Engineer, Online Games, San Francisco-CA, Unity Technologies',
#  'ADMA, Australia, Chief Analytics Officer, IAPA, Sydney',
#  'Machine Learning, Online Education, Victor Lavrenko, Youtube',
#  'London-UK, Online Dating, Predictive Analytics, Recommendations, Thomas Levi, Top stories',
#  'NLP, Reformer, Transformer',
#  'Adaboost, Ensemble Methods, Machine Learning, Python',
#  'Israel, Recommendation, Software Engineer, Xbox',
#  'Beginners, Machine Learning, Mistakes, Outliers, Regression, Regularization, Time Series',
#  'Deep Learning, Machine Learning, Open Source, Python, Top tweets',
#  'Bangalore-India, Research Scientist, Text Analytics, Xerox',
#  'CA, Data Scientist, Finance, San Carlos, Upstart',
#  'Google, Sciforce, TensorFlow, TPU',
#  'Business, Gartner, Hadoop, Ingo Mierswa, Merv Adrian, Predictive Analytics, RapidMiner',
#  'Machine Learning, Tips',
#  'Big Data Analytics, Business Analytics, Certificate, Online Education, R, Statistics, Statistics.com',
#  'AISC, BERT, NLP, Training, Transformer',
#  'Finance, R, Time Series, XGBoost',
#  'Clustering, Customer Analytics, Histogram, K-means, Yhat',
#  'Continuum Analytics, Data Science, Data Science Tools, Jupyter',
#  'CA, Data Mining, Data Science, Palo Alto, Robert Tibshirani, Statistical Learning, Trevor Hastie',
#  'Machine Learning, NLP, NLTK, Python, Tokenization',
#  'Analytics, Edge Analytics, IoT, Sensors',
#  'Backpropagation, Deep Learning, Machine Learning, Neural Networks',
#  'Data Science, India, Regression',
#  'DC, Dubai, Online Education, Predictive Analytics, The Modeling Agency, TMA, Washington',
#  'Blacksburg-VA, Computational Modeling, Data Analytics, Faculty, Virginia Tech',
#  'Data Engineering, Health Integrated, Manager, Tampa-FL',
#  'Analysis, Finance, Forecasting, Stocks, Time Series',
#  'Health, IoT, Modeling, Sports',
#  'Machine Learning, Report, Survey',
#  'Deployment, Kaggle, Lukas Biewald, Machine Learning, Project Fail, Training Data',
#  'Deep Learning, Feature Extraction, Machine Learning, Neural Networks, TensorFlow',
#  'Apache Spark, Data Infrastructure, Hadoop',
#  'Deep Learning, Dropout, Python, TensorFlow',
#  'Big Data, Data Science Education, Data Scientist',
#  'Apache Spark, Hadoop, James Kobielus',
#  'NLP, Python, Top tweets',
#  'Added to KDnuggets, Data Science Certificate, Data Science Education, Meetings, Open Data',
#  'Data Science, Domino, IT',
#  'Arena, Baltimore, Data Scientist, MD, New York City, NY',
#  'Big Data Analytics, Challenges, Kaushik Pal, Marketing Analytics',
#  'AI, Machine Learning, Optimization, Reinforcement Learning, Supervised Learning',
#  'Burlington, Data Analyst, Energy Analytics, USA, VT',
#  'Deep Learning, Misconceptions, Neural Networks',
#  'MBA, Online Education, TESC',
#  'Apache Spark, Databricks, White Paper',
#  'AI, Blockchain, CA, Data Science, Deep Learning, Industry, Machine Learning, Santa Clara',
#  'AI, Big Data Market, CAPTCHA, Google, Image Recognition, Microsoft, Salary',
#  'ARIMA, Data Science, Machine Learning, Prediction, Time Series',
#  'Boston, Competition, DrivenData, Yelp',
#  'AI, Bayesian Networks, Book, Causality, Causation, Judea Pearl',
#  'Advanced Analytics, Chicago, IL, PAW, Predictive Analytics World',
#  'AI, Deep Learning, Deployment, NVIDIA',
#  'Pandas, Python, Twitter',
#  'Data Visualization, Software Advice',
#  'Beginners, Neural Networks, R, Udemy',
#  'Data Scientist, Healthcare, Telecommute, UnitedHealth Group',
#  'Andrew Ng, CA, Deep Learning, DeepMind, RE.WORK, Research, San Francisco',
#  'Analytics, Applications, Bart Baesens, Big Data, Book, Data Science, Wiley',
#  'Data Mining, Data Science, Feature Extraction, Feature Selection, Machine Learning, Python',
#  'Chatbot',
#  'Hadoop, MADlib, SQL',
#  'Data Science, ETL, In-house, Interview, Joseph Babcock, Netflix, Open Source, Tools',
#  'Chicago, Hadoop, IL, PAW, Predictive Analytics World, Predictive Modeling, R',
#  'Analytics, Blogs, Data Science, Deep Learning, Machine Learning, Programming Languages',
#  'Autoencoder, Convolutional Neural Networks, Neural Networks, Python',
#  'Bayesian, Data Science, Data Science Team, Ontology',
#  'Machine Learning, New York-NY, Python',
#  'Career, Data Science, Data Science Skills, Data Scientist, Skills',
#  'Ari Lamstein, Maps, Online Education, R, US Census',
#  'free download, Intel, numpy, Python',
#  'Hadoop, Lavastorm, Logistic Regression, Salford Systems',
#  'change.org, Facebook, Highlights, Paxata, Santa Clara-CA, Strata 2014, SVDS',
#  'Algolytics, Data Mining, Data Science Jargon, Glossary',
#  'Deep Learning, Machine Translation, NLP, Recurrent Neural Networks',
#  'Correlation, Random',
#  'AI, Eric Siegel, Machine Learning, Safety',
#  'Datasets, GitHub, Machine Learning, Open Data',
#  'Analytica, Data Scientist, DC, Washington',
#  'Algorithms, Microsoft, Neural Networks',
#  'Baseball, OnlyBoth, Raul Valdes-Perez, Vivisimo',
#  'Crime, Data Science, Fishing, Ocean, United Nations',
#  'Data Science, Jeroen Janssens, Toolbox',
#  'Data Science Skills, Jupyter, Machine Learning, Pandas, R',
#  'Deep Learning',
#  'Cartoon, Machine Learning',
#  'Big Data, Climate Change, Oak Ridge, ORNL, Research Scientist, TN',
#  'Data Science Platform, Forrester, Gartner, IBM, Knime, Machine Learning, Mike Gualtieri, Predictive Analytics, RapidMiner, SAS',
#  'Machine Learning, Neural Networks, Python, PyTorch',
#  'Data Science Skills, Data Scientist, John Snow Labs, Online Education',
#  'Dark Knowledge, Deep Learning, Geoff Hinton, Neural Networks, Ran Bi',
#  'Data Science, Data Science Team',
#  'Developers, Internet of Things, IoT, Java',
#  'Dash, Data Visualization, Open Source, Plotly, Python',
#  'Adversarial, Cartoon, Deep Learning, Self-Driving Car',
#  'Analytics Specialist, Bain, Boston-MA, Los Angeles-CA, New York-NY, San Francisco-CA',
#  'Interpretability, Keras, Machine Learning, Model Performance, NLP, Overlook, Recurrent Neural Networks, Visualization',
#  'Berlin, Germany, PAW, Predictive Analytics World',
#  'Churn, Customer Analytics, Datascience.com, Survival Analysis',
#  'Big Data, DeZyre, Fraud Detection, Security',
#  'Google, Maps, Octoparse, Web Scraping',
#  'Advice, Analytics, Data Science, R',
#  'Data Exploration, Data Visualization, JMP',
#  'Analytics, Columbus, Cummins, IN',
#  'Data Visualization, Sentiment Analysis, Text Mining',
#  'Competition, Health, Microsoft, Women',
#  'AI, Architecture, Bradenton, FL, Foot Locker, Machine Learning',
#  'Accuracy, Balancing Classes, Machine Learning, Model Performance, Sports',
#  'Biotech, Contract positions, Data Scientist, NLP, San Diego-CA',
#  'Paychex, Payroll, Rochester-NY',
#  'Boston-MA, Data Scientist, Thomson Reuters',
#  'Analytics, Analytics Strategy, Culture, Strategy',
#  'Cloud Computing, Data Architect, Microsoft, Microsoft Azure, New York City, NY',
#  'C++, Deep Learning, Matthew Mayo, Neural Networks, Python, R, Reddit',
#  'Cheat Sheet, Jupyter, Python, Top tweets',
#  'Business Analytics, Certificate, Certification, Data Science Certificate, Education, Machine Learning, Online Education, SAS Certification',
#  'NPD, NY, Port Washington, USA, Validation',
#  'AI, Global Big Data Conference, New York City, NY',
#  'Deep Learning, fast.ai, Kaggle, Neural Networks, Rachel Thomas, word2vec',
#  'AI, Amazon, Azure ML, Cloud, Google, Google Cloud, Machine Learning, Microsoft, MLaaS, Sagemaker',
#  'Bitcoin, Data Science Education, Datasight.io, Machine Learning, MIT',
#  'Amazon, Deep Learning, NIPS, Open Source, Recommendations, Terrorism',
#  'Cosmology, Machine Learning, Python',
#  'Copyright Clearance Center, Linguamatics, Text Mining',
#  'Chicago, IL, Modeling, PAW, Predictive Analytics, Predictive Analytics World',
#  'Data Science, Deep Learning, Image Recognition, Udemy',
#  'AWS, Cloud Computing, Google Cloud, Microsoft Azure',
#  'Belgrade-Serbia, Nordeus',
#  'Algorithmia, API, Cloud, Deep Learning, Diego Oppenheimer',
#  'Deep Learning, Germany, Munich, PAW',
#  'Analytics, Australia, IAPA, Melbourne',
#  'Data Visualization, Plotly',
#  'Artificial Intelligence, Machine Learning, Strata',
#  'Biometrics, Competition',
#  'Deep Learning, Facebook, Google, Machine Learning, TensorFlow, Torch, Zachary Lipton',
#  'Insurance, R&D, Toronto-Canada, Travelers',
#  'Acquisitions, startups, VC',
#  'Book, Data Science, Ian Goodfellow, Machine Learning, Mathematics, Robert Tibshirani, Vladimir Vapnik',
#  'Certificate, Data Science, Data Science Certificate, Online Education, Stanford',
#  'Data Science Platform, Docker, Jen Underwood, Jupyter, R, R-Brain',
#  'Big Data, Data Visualization, Deep Learning, Jupyter, Machine Learning, Python, R, Tableau',
#  'Basking Ridge, Business Intelligence, Manager, NJ, Verizon',
#  'Data Science, Drexel University, PA, Philadelphia, Postdoc',
#  'AI, Machine Learning',
#  'Certificate, Data Science Certificate, Netflix, Neural Networks, numpy, Top tweets',
#  'Austin, Data Scientist, TX, Zynga',
#  'Big Data, Hadoop, TED, Tutorials, Youtube',
#  'Big Data, Boston-MA, Data Mining, Data Science, London-UK, San Francisco-CA',
#  'Atari, Deep Learning, OpenAI, Reinforcement Learning',
#  'Big Query, Deep Learning, Google, Mode Analytics, Netflix, R',
#  'Academics, Dortmund, Germany, Research, TU Dortmund',
#  'Data Quality, Face Recognition, IMDb, Kaggle, Movies',
#  'Big Data, Innovation, Knime, Open Analytics',
#  'Data Science, DataKind, DataLook, Social Good',
#  'Alex Jones, Algorithms, Business Leader, Classification, Data Analytics, Decision Trees, Linear Programming, Regression',
#  'Data Science, DeZyre, Ecommerce, Recommendations',
#  'Big Data, Data Architect, IBM, USA',
#  'Data Scientist, Machine Learning, Programming, Python',
#  'Director, LoyaltyOne, MA, Westborough',
#  'Advice, Bias, Big Data, Privacy, Security',
#  'Analytics, Insight X Network, Marketing, Metrics, New York City, NY, Summit',
#  'Boston, CA, Chicago, London, MA, San Diego, San Francisco, UK, USA',
#  'Data Visualization, Kanri, Metrics, Software',
#  'Manager, Marketing Analytics, Minneapolis, MN, SapientNitro',
#  'Cincinnati, OH, Professor, University of Cincinnati',
#  'CO, Data Scientist, Louisville, Path2Response',
#  'Air Liquide, Newark-DE, Research Scientist',
#  'Algorithms, Machine Learning, Reinforcement Learning, Statsbot, Supervised Learning, Unsupervised Learning',
#  'Hadoop, New York City, NY, Strata',
#  'Data Analytics, MS in Analytics, Penn State',
#  'Advice, Ian Goodfellow, Machine Learning, Quora, Top 10, Xavier Amatriain, Yoshua Bengio',
#  'AI, Automation, Industry, Machine Learning, Robots',
#  'Big Data, Google Trends, New York City, NY, PAW, Predictive Analytics World',
#  'Australia, Lecturer, Melbourne, Monash University, Optimization',
#  'AI, API, Data Science, Data Scientist, Health, Key Terms, Machine Learning, Math, Neural Networks, Python',
#  'Automated Data Science, Data Science, Data Science Platform, Mode Analytics',
#  'AnalyticsWeek, Automating, Big Data, Boston-MA, Gregory Piatetsky, Next Big Thing, Panel, Paul Sonderegger, Privacy',
#  'Clustering, Text Analytics, Unstructured data',
#  'Deep Learning, Fake News, Jeremy Howard, Machine Learning, Process Mining',
#  'AI, Deep Learning, Disentanglement, NeurIPS, Representation, Research',
#  'Data Classification, Data Science Education, Markov Chains, Master of Science, Open Source, Python',
#  'Apache Mahout, Data Scientist, Ensemble Methods, Machine Learning, scikit-learn',
#  'Europe, Machine Intelligence, Machine Learning, startups',
#  'Australia, Python, Python vs R, R',
#  'Minnetonka, MN, Project Manager, UnitedHealth Group',
#  'Apache, Big Data, Data Management, Hadoop, Java, NoSQL',
#  'Apache Spark, Data Preparation, Databricks, ebook',
#  'Certificate, Mining Massive Datasets, Online Education, Stanford',
#  'AT&T, Chicago, IE Group, IL, Predictive Analytics, Time Warner Cable, USA, Verizon',
#  'AI, Fellowship, Mozilla, Research',
#  'Applied Statistics, Big Data, Google, Statistics',
#  'Deep Learning, ICML, Machine Learning, Natural Language Processing, Neural Networks, Optimization',
#  'MS in Data Science, Online Education, Statistics.com',
#  'Big Data, Data Mining Software, Deep Learning, Poll, Python, Python vs R',
#  "London, O'Reilly, Strata, UK",
#  '7 Steps, Convolutional Neural Networks, Deep Learning, Keras, Logistic Regression, LSTM, Machine Learning, Neural Networks, Python, Recurrent Neural Networks',
#  'Advice, Career, Data Science Skills, Skills',
#  'CleverTap, Market Analytics, Predictive Analytics, Trends',
#  'Data Discovery, Healthcare, Io-Tahoe',
#  '7 Steps, Classification, Clustering, Jupyter, Machine Learning, Python, Regression',
#  'Algobeans, Feature Selection, Food, Nutrition, PCA',
#  'Collinearity, Data Preparation, Data Science, Data Visualization, Machine Learning, Missing Values, Mistakes',
#  'Boston, Chicago, London, Meetings, New York City, San Francisco, UK, Washington',
#  'Data types, Hadoop, NoSQL, Poll, Relational Databases',
#  'Data Science, Real Estate, Warsaw, Web Scraping',
#  'Amazon, API, Google Cloud, IBM Watson, Microsoft Azure, NLP, Speech Recognition',
#  'CA, Data Scientist, Esri, Redlands',
#  'Big Data, Business Context, Business Strategy, Economics',
#  'Deep Learning, NLP, Word Embeddings, word2vec',
#  'Alpine, Data Science, Periodic-Table, Strata 2014',
#  'Clustering, Deep Learning, TensorFlow, Text Analytics',
#  'Chief Analytics Officer, Corinium, Forum, New York City, NY',
#  'Master of Science, MS in Analytics, Northwestern, Online Education',
#  'Dispersion, RideOnData, Statistics',
#  'Data Scientist, London, Massive Analytic, Python, Scala, UK',
#  'Healthcare, Machine Learning Engineer, PeachIH, Singapore',
#  'Credit Risk, Hamburg-Germany, Kreditech',
#  'Cartoon, Python, Recommendations',
#  'CA, Deep Learning, Developer, Engineer, NVIDIA, Santa Clara, Self-Driving Car',
#  'A/B Testing, Big Data Hype, Correlation, Interview, Juan Lavista, Microsoft',
#  'BigML, Machine Learning, Predictive Models',
#  'Communication, Data Science, Storytelling',
#  'Advice, Pandas, Python, Top tweets',
#  'Analytics, Data Science, Durham, Faculty, Lecturer, NH, University of New Hampshire',
#  'Classification, Explained, Linear Regression, Logistic Regression, Probability',
#  'AI, Artificial Intelligence, History, ImageNet',
#  'Chicago, IL, Insight X Network, Marketing Analytics, Metrics',
#  'Analytics, IoT, Telecom',
#  'AGI, AI, Artificial Intelligence, Neuroscience',
#  'Data Science, Data Visualization, Open Data, World Bank',
#  'AI, Compression, Convolutional Neural Networks, Image Recognition',
#  'Bootcamp, FL, Global Big Data Conference, Tampa',
#  'CT, Manager, Marketing Analytics, Purdue Pharma, Stamford',
#  'Certificate, Data Mining, Finance, Online Education, Stanford',
#  'Austin, Big Data Engineer, New York City, NY, TeamSoft, TX',
#  'Cognitive Computing, DataRPM, Kirk D. Borne, Predictive Maintenance',
#  'CA, PAW, Predictive Analytics World, San Francisco, Text Analytics, USA, Workforce Analytics',
#  'Apache Spark, Deep Learning, Deepak Agarwal, Devendra Desale, Doug Cutting, Hadoop, Security, Strata',
#  "IN, MS in Data Science, Notre Dame, Saint Mary's College",
#  'Advice, Data Science, Data Scientist',
#  'Anaheim, Bootcamp, CA, Data Science, TDWI',
#  'Bootcamp, CA, Data Science, Keras, San Jose, SFbayACM, TensorFlow',
#  'Apache, Cloud Computing, Relational Databases',
#  'Agro, Data Visualization, DuPont, IA, Johnston',
#  'Deep Learning, Neural Networks, NLP',
#  'Challenges, Data Quality',
#  'Big Data, Big Data Hype, Germany',
#  'Apple, CA, Cupertino, Data Scientist, Manager',
#  '2018 Predictions, AI, Machine Learning, Xavier Amatriain',
#  'Clustering, Machine Learning, Python',
#  'Data Science, Pandas, Python',
#  'Marketing Analytics, SapientNitro',
#  'Big Data, Machine Learning, Podcast, TED',
#  'Culture, Data Science Team, Hiring, Team',
#  'Convolutional Neural Networks, Deep Learning, Deep Neural Network, Neural Networks, Podcast, Speech',
#  'Canada, Data Scientist, TD, Toronto',
#  '2017 Predictions, Data Science, Deep Learning, random forests algorithm',
#  'Career, Data Analyst, Data Engineer, Data Scientist, DataCamp, Infographic, Statistician',
#  'Domino, Machine Learning, Metrics, Monitoring, Production',
#  'GitHub, Machine Learning, Matthew Mayo, Open Source, scikit-learn, Top 10',
#  'Cheat Sheet, Data Visualization, Deep Learning, DeepMind, Demis Hassabis, Facebook, IPython, Python',
#  '8451, Cincinnati, OH, Scientific Developer',
#  'Analytics, Business Intelligence, Looker, Police, Products',
#  'New York City, NY, PAW, Predictive Analytics, Predictive Analytics World',
#  'CA, Facebook, Google, Innovation, Intel, LinkedIn, Predictive Analytics, San Diego',
#  'Career, Data Science, Data Science Education',
#  'Advice, Analytics, Berg, Challenges, Healthcare, Interview, Slava Akmaev, Trends, Use Cases',
#  'Climate Change, Science, United Nations',
#  'Azure ML, Louis Dorard, Machine Learning, Marketplace, Microsoft Azure, PredictionIO',
#  'Analyst, Cardinal Financial, Charlotte, Marketing, NC, USA',
#  '3Vs of Big Data, Humor',
#  'API, Deep Learning, Fashion, Hiring, Machine Learning, R',
#  'Bootcamp, CA, Data Science Education, Metis, New York City, NY, San Francisco',
#  'Machine Learning, R, Sampling, Statistics',
#  'GDPR, Google, Machine Learning, Pedro Domingos, Privacy',
#  'About KDnuggets, Blogs, Top bloggers',
#  'Databases, Explained, Graph Databases, Key Terms, NoSQL, RDBMS, Relational Databases, SQL',
#  'LSTM, Neural Networks, PyTorch, Recurrent Neural Networks',
#  'Analytics, Multicollinearity, Regression, Statistics',
#  'Analytics Specialist, Chubb, Insurance, Whitehouse Station-NJ',
#  'Alteryx, Apache Spark, Big Data Influencers, Data Analyst, Data Scientist, Databricks',
#  'Marketplace, Privacy, startups',
#  'BI, Data Analytics, Data Science, James Kobielus, Online Education',
#  'Faculty, NY, Professor, Utica, Utica College',
#  'Master of Science, MS in Analytics, MS in Business Analytics, MS in Data Science, Online Education',
#  'Analysis, Data Science, Humor',
#  'ACM, Apache Spark, Bootcamp, CA, Data Science, R, San Jose, SFbayACM',
#  'Differential Privacy, Explanation, Nina Zumel',
#  'Book, Brendan Tierney, Data Mining, Oracle, Predictive Analytics',
#  'Business, Citizen Data Scientist, Skills',
#  'Advice, Big Data, Cloudera, ecosystem, Eli Collins, Strategy, Trends, Vendors',
#  'Data Preparation, Data Preprocessing, NLP, Text Analytics, Text Mining, Tokenization',
#  'Challenge, Cognitive Computing, HeroX',
#  'Chatbot, Neural Networks, Python vs R, Recommender Systems, Top tweets',
#  'Deep Learning, Google, Machine Learning, Matthew Mayo, Python, TensorFlow',
#  'Deep Learning, Image Recognition, R',
#  'Explained, Neural Networks',
#  'Boston, MA, MGH, Postdoc, Research Scientist',
#  'Apache Spark, IBM, Twitter, Watson',
#  'Big Data, Michael Jordan',
#  'Algorithms, Clustering, Decision Trees, K-nearest neighbors, Machine Learning, PCA, Poll, random forests algorithm, Regression, Statistics, Text Mining, Time Series, Visualization',
#  'CUNY, Erdos, Facebook, Mathematics, MS, Online Education, Relationships, Women',
#  'Bradenton, Data Analyst, FL, Foot Locker, Wausau, WI',
#  'AI, Amsterdam, Deep Learning, DeepMind, Facebook, London, Netherlands, OpenAI, RE.WORK, UK',
#  'CMSR, Cramer, Rosella Software, Rule Engines, Sequential Rule Engine',
#  'Advice, Career, Data Science, Job, Salary',
#  'Amazon, Analytics, Product reviews, Sentiment Analysis, Text Analytics, Text Mining',
#  'DeZyre, Python, Python vs R, R',
#  'Algorithms, Machine Learning, Regression, Trends',
#  'Data Visualization, Engineer, Equifax, MO, St. Louis',
#  'AI, Faculty, Machine Learning, Switzerland, Zurich',
#  'PAW, Predictive Analytics World, Uplift Modeling',
#  'Career, Data Science Skills, Geert Verstraeten, Public Speaking',
#  'CA, Columbia, Data Engineer, Data Science, Data Scientist, Engineer, MD, San Francisco, SparkPost',
#  'Arlington, Data Engineer, VA, Virginia Tech',
#  'API, Data Science, Face Recognition, IBM Watson, Image Recognition, Machine Learning, NLP, Sentiment Analysis',
#  'Data Science Education, Data Visualization, DataCamp, Online Education, Python, R',
#  'Apache Spark, Conference, Facebook, Games, Gaming Analytics, Highlights, IE Group, Prediction',
#  'Big Data, Cosmology, Physics, Science, Strata',
#  'Business Intelligence, Cloud Analytics, Data Mining, Health, Predictions for 2015, Social Analytics',
#  'AlgoMost, Competition, Graph Analytics, Social Networks',
#  'Anomaly Detection, Cartoon, Data Scientist, Deep Learning, Dilbert, Marc Andreessen, Twitter',
#  'A/B Testing, Analytics, Bradenton, FL, Foot Locker',
#  'Austin, Big Data, Bootcamp, Developers, Global Big Data Conference, TX',
#  'Neural Networks, NLP, Recurrent Neural Networks, Sequences',
#  'Big Data, Largest, Poll',
#  'Big Data, Data Engineering, Database',
#  'Apache Spark, Data Science Platform, Dataiku, R, Spark SQL, SQL',
#  'Data Visualization, OpenText, Statistics, United Nations',
#  'Amsterdam, Competition, Hackathon, McKinsey, Stockholm, Zurich',
#  'Consulting, Harvard, Marketplace, Startup',
#  'Arno Candel, Deep Learning, H2O, HPC, Resources, Trends, Use Cases',
#  'Boston, Data Science, Data Science Education, Director, MA, Northeastern',
#  'Balancing Classes, Data Preparation, Data Science, Unbalanced',
#  'Apache Spark, Data Science, Data Scientist, Databricks, Free ebook',
#  'Bernie Sanders, Donald Trump, Hillary Clinton, ParseHub, Politics, Sentiment Analysis, Twitter',
#  'Data Science Dojo, R, Web Scraping',
#  'Career, Data Science, Interview questions, Kaiser Fung',
#  'Microsoft, NLP, Reinforcement Learning',
#  'API, Data Mining Training, Python, SlideShare',
#  'Data Analytics, Scientist, Singapore',
#  'Cambridge, Computer Vision, FeatureX, MA, Machine Learning, Software Engineer',
#  'Analyst, Energy, Irving-TX, Statistical Modeling, TXU Energy',
#  'GANs, Generative Adversarial Network, Neural Networks',
#  'Charu Aggarwal, Frequent Pattern Mining, Jiawei Han',
#  'Deep Learning, Machine Learning, MOOC, Overlook, Support Vector Machines',
#  'AI, Facebook, Poker',
#  'Amazon, Books, Data Mining, Data Science',
#  'AI, Data Engineering, Data Science Education, DSTI, France, Master of Science, Paris',
#  'CA, IE Group, Innovation, London, San Francisco, UK',
#  '7 Steps, Classification, Cross-validation, Dimensionality Reduction, Feature Engineering, Feature Selection, Image Classification, K-nearest neighbors, Machine Learning, Modeling, Naive Bayes, numpy, Pandas, PCA, Python, scikit-learn, Transfer Learning',
#  'Big Data, Conference, Experimentation, Healthcare, London-UK, Market Research, Predictive Analytics',
#  'San Francisco-CA, Text Analytics, Unstructured data, Yahoo',
#  'Big Data Market, Market Forecast, Mu Sigma, Palantir, Pivotal, Splunk, Wikibon',
#  'Deep Learning, Neural Networks, PyTorch, TensorFlow',
#  'Cartoon, Data Science, Deep Learning, Netflix, Overfitting, Soccer, Top stories',
#  'Arno Candel, Deep Learning, H2O',
#  'Deep Learning, numpy, Python, Software Engineer, Top tweets',
#  'ADMA, Australia, Melbourne, Star Wars, Sydney',
#  'Berlin, Big Data Engineer, Germany, Hellofresh',
#  'AI, Career, Machine Learning',
#  'Analytics, Big Data',
#  'Apache Spark, Hadoop, London, Strata, UK',
#  'Algorithms, Learning, Machine Learning, Tom Mitchell',
#  'Convolutional Neural Networks, Dropout, Keras',
#  'Deep Learning, Neural Networks, Python, PyTorch',
#  '2017 Predictions, Bayesian, Big Data, Data Science, Neural Networks, Poll',
#  'DATAx, IE Group, Singapore',
#  'AI, Artificial Intelligence, Poll, Threat to Humanity',
#  'Linear Regression, Predictive Modeling, R',
#  'Data Science, Europe, London, ODSC, UK',
#  'CA, Data Scientist, HomeUnion, Irvine, USA',
#  '2016 Predictions, FICO, Prescriptive Analytics, Streaming Analytics',
#  'Bing Liu, Natural Language Processing, NLP, Text Analytics, Text Mining',
#  'AI, DataRobot, Predictions',
#  'Bart Baesens, OLAP, SQL',
#  'Apache Superset, Bitcoin, Investment, Sentiment Analysis, Time Series, Twitter',
#  'Advice, Decision Making, Education, Interview, Kirk D. Borne, Skills, Syntasa',
#  'Domino, Forrester, Machine Learning, Predictive Analytics',
#  'CA, Data Science, Marketing Analytics, San Francisco',
#  'Austin, Bootcamp, Boston, CA, FL, Global Big Data Conference, MA, NC, Raleigh, San Francisco, Seattle, Tampa, TX, WA',
#  'Big Data, Business, CA, San Jose, Strata',
#  'Cheat Sheet, ebook, Top tweets',
#  '2019 Predictions, AI, Analytics, Data Science, Domino, dotData, Figure Eight, Industry, Knime, Machine Learning, MapR, MathWorks, OpenText, ParallelM, Salesforce, Splice Machine, Splunk',
#  'Awards, Data Mining, Data Science, ICDM, IEEE, Research',
#  'Interview, Learning from Data, Santhosh Adayikkoth, Skills, Startup',
#  'Andrew Ng, Data Science, Data Scientist, Deep Learning, Machine Learning',
#  'Apache Spark, Graph Databases',
#  'Agile, Data Science, Data Science Team, SVDS',
#  'DeepMind, Geoff Hinton, Image Recognition, Machine Learning, Neural Networks, Reddit, Self-Driving Car',
#  'Cartoon, Free ebook, Machine Learning, Massachusetts, Top stories',
#  'Deep Learning, Deployment, Exxact, TensorFlow',
#  'Developer, Farmington Hills, MI, Morpace, SQL',
#  'Analytics, Checklist, Deployment, Feature Selection, Statistics',
#  '50 Shades of Grey, Divorce, Electric Car, Envia, Image Recognition, R, Sports, Wedding',
#  ...}

# %% [markdown]
# Just looking at the top of the tags, I'm gonna guess that we're dealing with a few categories of tags:
#
# 1. several very common tags like 'AI', 'Machine Learning', 'Data Science', 'Pandas', 'R', ...
#
# 2. some tags that come up less frequently but that may be common enough to be useful and indicate content such as 'Privacy', 'Self-Driving Car', 'LSTM', 'NIH'
#
# 3. a third group of tags that may helpful for content but occur infrequently in the scope of the whole dataset, like the names of startups and not-so-well-known technologies
#
# 4. tags that are not really of interest to us wrt what we want to train on, like the word 'Trends' or 'Faculty' or an author's name that occurs only once as a tag for some reason.
#
# There are also lots of tags that are more or less duplicates of each other, like ML and 'Machine Learning', as noted above, that we'll end up combining as we ultimately try to decrease the number of unique tags we have to learn.
#
# Keep in mind that that there are only tags starting in 2014.

# %% [markdown]
# ## Variable Preprocessing

# %% [markdown]
# ### Article 'tags' preparation

# %%
tags = [str(i) for i in tags]
type(tags)
# Out:
# list

# %%
# split 'tags' into list of lists of tag strings
print(tags[2000])
tags_split = [t.split(sep=', ') for t in tags]
print(tags_split[2000])
# Out:
# Advice, Apache Mahout, Apache Spark, H2O, Interview, Machine Learning, MapR, Ted Dunning
# ['Advice', 'Apache Mahout', 'Apache Spark', 'H2O', 'Interview', 'Machine Learning', 'MapR', 'Ted Dunning']

# %%
# Flatten tag lists into one long list of individual tags 
tags_flattened = [t for t_list in tags_split for t in t_list]
tags_flattened[2000:2010]
# Out:
# ['Healthcare',
#  'Pennsylvania',
#  'Coursera',
#  'Data Science Education',
#  'EMC',
#  'Free ebook',
#  'LinkedIn',
#  'Apple',
#  'Austin-TX',
#  'Big Data Vendors']

# %% [markdown]
# #### Common tags

# %%
from collections import Counter

tags_counts = Counter(tags_flattened)
most_common_tags = sorted(tags_counts.items(), key=lambda x: x[1], reverse=True)[:10]
#Counter(tags_flattened).keys()
#Counter(tags_flattened).values()

print(most_common_tags)
# Out:
# [('Machine Learning', 1368), ('Data Science', 1256), ('Deep Learning', 897), ('Python', 873), ('Data Scientist', 735), ('AI', 607), ('Big Data', 595), ('CA', 460), ('Neural Networks', 392), ('Top stories', 385)]

# %%
tag_counts = sorted(tags_counts.items(), key=lambda x: x[1], reverse=True)

# %%
common_tags_df = pd.DataFrame(tag_counts, columns=['Tag', 'Count'])
common_tags_df.head()
# Out:
#                 Tag  Count
# 0  Machine Learning   1368
# 1      Data Science   1256
# 2     Deep Learning    897
# 3            Python    873
# 4    Data Scientist    735

# %%
tags_df = pd.DataFrame(tag_counts, columns=['Tag', 'Count'])
tags_df.tail(10)
# Out:
#                   Tag  Count
# 3789      Model Drift      1
# 3790     Data Catalog      1
# 3791    Netflix Prize      1
# 3792       Lucidworks      1
# 3793  Disentanglement      1
# 3794         Reformer      1
# 3795      Monte Carlo      1
# 3796        AutoKeras      1
# 3797               IT      1
# 3798          ModelDB      1

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

fig = plt.figure()
fig.patch.set_facecolor('white')
n_top = 20

_ = sns.barplot('Tag', 'Count', data=tags_df[:n_top])
_ = plt.xlabel('Common Tags')
_ = plt.ylabel('Count')
_ = plt.xticks(rotation=45, ha='right', fontsize=11)
_ = plt.title('Top '+str(n_top)+' Most Common Tags')
plt.show()

# %% [markdown]
# ### Text Preparation for NLU - Article Body

# %% [markdown]
# #### Text Cleaning

# %% [markdown]
# We'll now clean up our text. For these article bodies from raw html it involves a few important steps:
#
# 1. Removing the line breaks denoted by \r and \n
#
# 2. Removing symbols like brackets, commas, colons, '@', for instance we get a lot of twitter ids within this text.
#
# 3. Removing urls
#
# 4. Removing inline Javascript that occurs in some of the articles
#
# 5. Removing English stopwords
#
# 6. Setting all to lowercase*
#
# 7. Removing extra whitespace, whether originially in the text or introduced by our cleaning process
#
#
#
# *May or may not modify this to retain uniqueness of certain named entities. e.g. the word 'data' vs. a company called 'Data, Inc.'. I think it's fine to lowercase everything because these sorts of named entities will mostly be picked up in our bi and trigrams if they really are common enough to matter.

# %%
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

LINEBREAKS_RE = re.compile('(\r\n|\r|\n)')
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('([^0-9a-z #+_]|http\S+)')
STOPWORDS = set(stopwords.words('english'))

def text_prepare(text):
    """
        text: a string
        
        return: modified initial string
    """
    # remove javascript at the end of some articles:
    text = text.split("var disqus_shortname = 'kdnuggets'", 1)[0]
    # lowercase text
    text = text.lower() 
    # replace LINEBREAKS_RE by single spaces in text:
    text = re.sub(LINEBREAKS_RE, " ", text)  
    # replace REPLACE_BY_SPACE_RE symbols by space in text:
    text = re.sub(REPLACE_BY_SPACE_RE, " ", text) 
    # delete symbols which are in BAD_SYMBOLS_RE from text:
    text = re.sub(BAD_SYMBOLS_RE, "", text) 
    
    text = " " + text + " "
    # delete stopwords from text:
    for sw in STOPWORDS:
        text = text.replace(" "+sw+" ", " ") 
    
    text = re.sub('[ ][ ]+', " ", text)
    if text[0] == ' ':
        text = text[1:]
    if text[-1] == ' ':
        text = text[:-1]
        

    return text
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\weswa\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
articles = articles.loc[articles['post_text'] != '']
len(articles)
# Out:
# 9394

# %%
#articles.loc[articles['post_text'] == '']
# articles['post_text'].apply(lambda x: len(x)).min()

# %%
text_series[0]
# Out:
# 'Gregory Piatetsky, Nov 15, 2013.\nOnalytica has done an interesting analysis of Big Data influencers on Tweeter.\nThey took the tweets for the last 6 months containing the hashtag #BigData and treated mentions of other tweeters as a link. This initial network was made up of about 150,000 nodes. After removing isolated components, they ranked the nodes by PageRank.\nThe methodology is different from their previous Big Data ranking based on Betweenness Centrality. Onalytica says that Betweenness Centrality puts connectors higher, but they found that PageRank more effectively highlights the real influencers in the network.\nOf course, no two rankings will be exactly the same, so for comparison I also added Klout, which considers not only Tweeter, but also Facebook, LinkedIn and other networks. Here are the top 20 entries in Onalytica list.\n\n\nOnalytica\nRank\nName\nTwitter\nTwitter\nFollowers\nKlout\n\n\n1 \nKirk Borne\n@KirkDBorne\n6,643\n 65\n\n\n2 \nJames Kobielus\n@jameskobielus\n10,624\n 55\n\n\n3 \nTimo Elliott\n@timoelliott\n10,768\n 64\n\n\n4 \nBernard Marr\n@BernardMarr\n67,792\n 68\n\n\n5 \nGregory Piatetsky\n@kdnuggets\n14,395\n 67\n\n\n6 \nThor Olavsrud\n@ThorOlavsrud\n1,083\n 51\n\n\n7 \nPhil Simon\n@philsimon\n3,908\n 64\n\n\n8 \nBrian Eastwood\n@Brian_Eastwood\n2,420\n 60\n\n\n9 \nR Ray Wang\n@rwang0\n41,075\n 70\n\n\n10 \nE.G.Nadhan\n@NadhanAtHP\n621\n 52\n\n\n11\nMike Gualtieri\n@mgualtieri\n37,263\n 59\n\n\n12\nSteve Lucas\n@nstevenlucas\n4,152\n 58\n\n\n13\nDoug Laney\n@Doug_Laney\n15,539\n 66\n\n\n14\nNatasha Bishop\n@Natasha_D_G\n1,526\n 62\n\n\n15\nDoug Henschen\n@DHenschen\n3,078\n 60\n\n\n16\nMichael Cavaretta\n@mjcavaretta\n2,040\n 56\n\n\n17\nKenneth Cukier\n@kncukier\n3,548\n 56\n\n\n18\nV Mayer-Schonberger\n@Viktor_MS\n1,095\n 51\n\n\n19\nJoab Jackson\n@Joab_Jackson\n4,418\n 57\n\n\n20\nSharon Machlis\n@sharon000\n2,024\n 60\n\n\nFor comparison, here are \nKlout Top Big Data Influencers, as of Nov 15, 2013.\nWe only see one name in common between Onalytica and Klout lists, which I am pleased to note is @kdnuggets.\nThe chart below shows there is no correlation between Onalytica rank and Klout. \nHere is Onalytica full list of 200 top Big Data influencers.'

# %%
clean_text = [text_prepare(x) for x in text_series]
print(clean_text[0])
# Out:
# gregory piatetsky nov 15 2013 onalytica done interesting analysis big data influencers tweeter took tweets last 6 months containing hashtag #bigdata treated mentions tweeters link initial network made 150 000 nodes removing isolated components ranked nodes pagerank methodology different previous big data ranking based betweenness centrality onalytica says betweenness centrality puts connectors higher found pagerank effectively highlights real influencers network course two rankings exactly comparison also added klout considers tweeter also facebook linkedin networks top 20 entries onalytica list onalytica rank name twitter twitter followers klout 1 kirk borne kirkdborne 6 643 65 2 james kobielus jameskobielus 10 624 55 3 timo elliott timoelliott 10 768 64 4 bernard marr bernardmarr 67 792 68 5 gregory piatetsky kdnuggets 14 395 67 6 thor olavsrud thorolavsrud 1 083 51 7 phil simon philsimon 3 908 64 8 brian eastwood brian_eastwood 2 420 60 9 r ray wang rwang0 41 075 70 10 egnadhan nadhanathp 621 52 11 mike gualtieri mgualtieri 37 263 59 12 steve lucas nstevenlucas 4 152 58 13 doug laney doug_laney 15 539 66 14 natasha bishop natasha_d_g 1 526 62 15 doug henschen dhenschen 3 078 60 16 michael cavaretta mjcavaretta 2 040 56 17 kenneth cukier kncukier 3 548 56 18 v mayerschonberger viktor_ms 1 095 51 19 joab jackson joab_jackson 4 418 57 20 sharon machlis sharon000 2 024 60 comparison klout top big data influencers nov 15 2013 see one name common onalytica klout lists pleased note kdnuggets chart shows correlation onalytica rank klout onalytica full list 200 top big data influencers

# %%
print(clean_text[11])
# Out:
# earn mba data analytics thomas edison state college school business management offers online mba area study data analytics prepares students thrive dynamic rapidly expanding field big data students equipped access analyze manage present data clevel leaders key organizational contributors enterprisewide program enables graduates use advanced data analytics drive continuous improvement resulting organizational sustainability mba program unique program length completed 18 months credit prior learning earn credit professional certifications expertise prerequisite courses select several options satisfying program prerequisites instructional delivery courses offered completely online affordability based 20132014 thomas edison state college cost estimate approximate cost completing mba 25 000 generally gmat required applicants possess undergraduate gpa 30 higher thomas edison state college one 11 senior public colleges universities new jersey accredited middle states commission higher education 3624 market street philadelphia pa 19104 2672845000 thomas edison state college 101 w state st trenton nj 086081176 888 4428372

# %% [markdown]
# I'd certainly consider whether to remove numbers, or at least numbers with more than 2 digits, like phone numbers and addresses

# %% [markdown]
# #### Lemmatization (w/ POS tagging)

# %%
# We'll do the final with Stanford CoreNLP if we notice improved quality, otherwise TextBlob is fine
from textblob import TextBlob, Word

# %%
# TextBlob implementation
def lemmatize_textblob(sentence):
    sent = TextBlob(sentence)
    tag_dict = {"J": 'a', 
                "N": 'n', 
                "V": 'v', 
                "R": 'r'}
    words_and_tags = [(w, tag_dict.get(pos[0], 'n')) for w, pos in sent.tags]
    lemmatized_list = [wd.lemmatize(tag) for wd, tag in words_and_tags]
    return " ".join(lemmatized_list)

# %%
sentence = "This is an excruciatingly confusing example sentence where the therapized coffee's mugs went to school"

# %%
lemmatize_textblob(sentence)
# Out:
# "This be an excruciatingly confusing example sentence where the therapized coffee 's mug go to school"

# %%
# try with one post text example
lemmatize_textblob(clean_text[0])
# Out:
# 'gregory piatetsky nov 15 2013 onalytica do interesting analysis big data influencers tweeter take tweet last 6 month contain hashtag bigdata treat mention tweeter link initial network make 150 000 node remove isolated component rank node pagerank methodology different previous big data rank base betweenness centrality onalytica say betweenness centrality put connector higher find pagerank effectively highlight real influencers network course two ranking exactly comparison also add klout considers tweeter also facebook linkedin network top 20 entry onalytica list onalytica rank name twitter twitter follower klout 1 kirk borne kirkdborne 6 643 65 2 james kobielus jameskobielus 10 624 55 3 timo elliott timoelliott 10 768 64 4 bernard marr bernardmarr 67 792 68 5 gregory piatetsky kdnuggets 14 395 67 6 thor olavsrud thorolavsrud 1 083 51 7 phil simon philsimon 3 908 64 8 brian eastwood brian_eastwood 2 420 60 9 r ray wang rwang0 41 075 70 10 egnadhan nadhanathp 621 52 11 mike gualtieri mgualtieri 37 263 59 12 steve lucas nstevenlucas 4 152 58 13 doug laney doug_laney 15 539 66 14 natasha bishop natasha_d_g 1 526 62 15 doug henschen dhenschen 3 078 60 16 michael cavaretta mjcavaretta 2 040 56 17 kenneth cukier kncukier 3 548 56 18 v mayerschonberger viktor_ms 1 095 51 19 joab jackson joab_jackson 4 418 57 20 sharon machlis sharon000 2 024 60 comparison klout top big data influencers nov 15 2013 see one name common onalytica klout list please note kdnuggets chart show correlation onalytica rank klout onalytica full list 200 top big data influencers'

# %%
# Stanford CoreNLP implementation
#  Start server with: 
#   \corenlp\stanford-corenlp-full-2018-10-05>java -mx4g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -annotators "tokenize,ssplit,pos,lemma,parse,sentiment" -port 9000 -timeout 30000

from stanfordcorenlp import StanfordCoreNLP
import json, string

def lemmatize_corenlp(conn_nlp, sentence):
    props = {
        'annotators': 'pos,lemma',
        'pipelineLanguage': 'en',
        'outputFormat': 'json'
    }

    # tokenize into words
    sents = conn_nlp.word_tokenize(sentence)

    # remove punctuations from tokenised list
    #sents_no_punct = [s for s in sents if s not in string.punctuation]

    # form sentence
    sentence2 = " ".join(sents) #" ".join(sents_no_punct)

    # annotate to get lemma
    parsed_str = conn_nlp.annotate(sentence2, properties=props)
    parsed_dict = json.loads(parsed_str)

    # extract the lemma for each word
    lemma_list = [v for d in parsed_dict['sentences'][0]['tokens'] for k,v in d.items() if k == 'lemma']

    # form sentence and return it
    return " ".join(lemma_list)


# make the connection and call `lemmatize_corenlp`
# nlp = StanfordCoreNLP('http://localhost', port=9000, timeout=30000)
# lemmatize_corenlp(conn_nlp=nlp, sentence=sentence)

# %%
# lemmatize_corenlp(nlp, clean_text[0])

# %% [markdown]
# This is just one example sentence but generally I prefer CoreNLP to other packages for lemmatization and certain other techniques like NER. TextBlob is what I like to use when I am just testing something real quick or I'm lazy and don't feel like starting up the CoreNLP server, because textblob is also a good package. The truth is you're never going to be perfect with stemming or lemmatization, because natural language is just so diverse and complex and there are so many exceptions to the rules. You can hardcode a certain number of common exceptions but it's not worth the trouble or bytes required. Plus even if you spend that much time on English, it's a similar investment to do the same for other languages if you need (although not all languages are as unneccessarily complex as English..).
#
# Anyway the existing packages and methods work fairly well in practice, though may have pros/cons depending on the situation.

# %%
# Before running keep in mind this'll take several minutes!
#lemmed_text = [lemmatize_corenlp(nlp, t) for t in clean_text]

# %%
# or
# lemmed_text = [lemmatize_textblob(t) for t in clean_text]

# %%
#lemmed_text[:5]

# %%
# For quick access in the future
# with open('kdn_lemmatized_text_corenlp.txt', 'w') as f:
#     for t in lemmed_text:
#         f.write("%s\n" % t)

# %% [markdown]
# #### Token Exploration

# %%
# Count most common words in post texts
post_words = [word for text in clean_text for word in text.split()] 
words_counts = Counter(post_words)

# %%
word_counts = sorted(words_counts.items(), key=lambda x: x[1], reverse=True)
print(word_counts[:100])
# Out:
# [('data', 124191), ('learning', 39716), ('science', 27773), ('analytics', 24624), ('machine', 24031), ('big', 17215), ('model', 15089), ('business', 15068), ('one', 14093), ('use', 13104), ('new', 12803), ('deep', 11904), ('also', 11678), ('using', 11383), ('1', 10458), ('models', 10329), ('time', 10304), ('ai', 9866), ('work', 9523), ('research', 9426), ('analysis', 9364), ('like', 9210), ('tco', 8966), ('experience', 8797), ('python', 8477), ('scientist', 8385), ('need', 8345), ('many', 8016), ('used', 7994), ('mining', 7968), ('get', 7754), ('information', 7585), ('top', 7569), ('may', 7509), ('make', 7410), ('training', 7259), ('well', 7218), ('2', 7190), ('see', 6884), ('first', 6732), ('predictive', 6702), ('different', 6676), ('us', 6664), ('code', 6607), ('scientists', 6546), ('tools', 6294), ('would', 6257), ('learn', 6256), ('r', 6250), ('neural', 6238), ('example', 6230), ('algorithms', 6168), ('related', 6147), ('team', 6102), ('world', 6039), ('best', 5997), ('people', 5959), ('set', 5951), ('software', 5830), ('skills', 5781), ('3', 5712), ('network', 5593), ('process', 5589), ('number', 5524), ('10', 5521), ('way', 5518), ('part', 5295), ('value', 5290), ('two', 5256), ('results', 5227), ('good', 5218), ('systems', 5176), ('years', 5173), ('help', 5149), ('kdnuggets', 5113), ('want', 5050), ('2015', 4970), ('features', 4964), ('networks', 4924), ('5', 4888), ('knowledge', 4881), ('intelligence', 4840), ('problem', 4834), ('based', 4813), ('applications', 4789), ('better', 4781), ('technology', 4759), ('2014', 4740), ('text', 4715), ('problems', 4685), ('know', 4627), ('language', 4622), ('even', 4592), ('image', 4453), ('companies', 4429), ('working', 4402), ('important', 4382), ('key', 4379), ('take', 4374), ('find', 4352)]

# %%
words_df = pd.DataFrame(word_counts, columns=['Word', 'Count'])
words_df.head()
# Out:
#         Word   Count
# 0       data  124191
# 1   learning   39716
# 2    science   27773
# 3  analytics   24624
# 4    machine   24031

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns
# %matplotlib inline

fig = plt.figure()
fig.patch.set_facecolor('white')
n_top = 20

_ = sns.barplot('Word', 'Count', data=words_df[:n_top])
_ = plt.xlabel('Common Words')
_ = plt.ylabel('Count')
_ = plt.xticks(rotation=45, fontsize=12)
_ = plt.title('Top '+str(n_top)+' Most Common Words')
plt.show()

# %% [markdown]
# Ultimately we'll probably use something like BoW or ngrams-TFIDF for this dataset because those models are simpler and tend to work better when you have smaller datasets. for so few articles as this a neural network like LSTM would probably be unnecessary. Save that for a tweets classification or something

# %% [markdown]
# Also see: "Topic modeling: a way to navigate through text collections", "PLSA", "the zoo of topic models" vids -week3 of C NLP course , particularly research Dynamic Topic Models

# %% [markdown]
# END CLEANING MODULE

# %% [markdown]
# ### Gensim doc/token prep

# %%
# Create token: id dictionary from text file (lemmatized docs)
import gensim
from gensim import corpora, models
from gensim.utils import simple_preprocess
# from smart_open import smart_open
# gensim dict
f = 'kdn_lemmatized_text_corenlp.txt'
dtm = [simple_preprocess(line, deacc=False) for line in open(f, encoding='windows-1252')]
# Out:
# C:\Users\weswa\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
dtm[0][:10]
# Out:
# ['gregory',
#  'piatetsky',
#  'nov',
#  'onalytica',
#  'do',
#  'interesting',
#  'analysis',
#  'big',
#  'datum',
#  'influencer']

# %%
print('chekc')
# Out:
# chekc

# %% [markdown]
# #### ngrams - bigrams &amp; trigrams

# %%
import warnings
warnings.filterwarnings('ignore')
# Build bigram and trigram models
bigram = gensim.models.Phrases(dtm, min_count=5, threshold=100)
trigram = gensim.models.Phrases(bigram[dtm], threshold=100)

# %%
# Faster to use Phraser class than raw Phrases()
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# View 1,2,3-grams example
print(trigram_mod[bigram_mod[dtm[0]]])
# Out:
# ['gregory_piatetsky', 'nov', 'onalytica', 'do', 'interesting', 'analysis', 'big', 'datum', 'influencer', 'tweeter', 'take', 'tweet', 'last', 'month', 'contain', 'hashtag', 'bigdata', 'treat', 'mention', 'tweeter', 'link', 'initial', 'network', 'make', 'node', 'remove', 'isolate', 'component', 'rank', 'node', 'pagerank', 'methodology', 'different', 'previous', 'big', 'datum', 'ranking', 'base', 'betweenness_centrality', 'onalytica', 'say', 'betweenness_centrality', 'put', 'connector', 'higher', 'find', 'pagerank', 'effectively', 'highlight', 'real', 'influencer', 'network', 'course', 'two', 'ranking', 'exactly', 'comparison', 'also', 'add', 'klout', 'consider', 'tweeter', 'also', 'facebook', 'linkedin', 'network', 'top', 'entry', 'onalytica', 'list', 'onalytica', 'rank', 'name', 'twitter', 'twitter_follower', 'klout', 'kirk_bear', 'kirkdborne', 'jame_kobielus', 'jameskobielus', 'timo', 'elliott', 'timoelliott', 'bernard_marr', 'bernardmarr', 'gregory_piatetsky_kdnugget', 'thor', 'olavsrud', 'thorolavsrud', 'phil_simon', 'philsimon', 'brian', 'eastwood', 'brian', 'eastwood', 'ray', 'wang', 'rwang', 'egnadhan', 'nadhanathp', 'mike_gualtieri', 'mgualtieri', 'steve', 'luca', 'nstevenluca', 'doug_laney', 'doug_laney', 'natasha', 'bishop', 'natasha', 'doug', 'henschen', 'dhenschen', 'michael_cavaretta', 'mjcavaretta', 'kenneth_cukier', 'kncukier', 'viktor', 'ms', 'joab', 'jackson', 'joab', 'jackson', 'sharon', 'machlis', 'sharon', 'comparison', 'klout', 'top', 'big', 'datum', 'influencer', 'nov', 'see', 'one', 'name', 'common', 'onalytica', 'klout', 'list', 'pleased', 'note', 'kdnugget', 'chart', 'show', 'correlation', 'onalytica', 'rank', 'klout', 'onalytica', 'full', 'list', 'top', 'big', 'datum', 'influencer']

# %% [markdown]
# Remember we're setting a min count and rather high threshold for the gensim Phrases, so not all possible instances will be merged into bi or trigrams. We don't want to use a much heavier model for the sake of terms that don't appear very often, particularly as this dataset will have a lot of infrequent names of people whom, to be blunt, we don't care about.

# %%
def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

# %%
dtm = make_trigrams(dtm)

# %%
token_dict = corpora.Dictionary(dtm)

# %%
token_dict.token2id
# Out:
# {'add': 0,
#  'also': 1,
#  'analysis': 2,
#  'base': 3,
#  'bernard_marr': 4,
#  'bernardmarr': 5,
#  'betweenness_centrality': 6,
#  'big': 7,
#  'bigdata': 8,
#  'bishop': 9,
#  'brian': 10,
#  'chart': 11,
#  'common': 12,
#  'comparison': 13,
#  'component': 14,
#  'connector': 15,
#  'consider': 16,
#  'contain': 17,
#  'correlation': 18,
#  'course': 19,
#  'datum': 20,
#  'dhenschen': 21,
#  'different': 22,
#  'do': 23,
#  'doug': 24,
#  'doug_laney': 25,
#  'eastwood': 26,
#  'effectively': 27,
#  'egnadhan': 28,
#  'elliott': 29,
#  'entry': 30,
#  'exactly': 31,
#  'facebook': 32,
#  'find': 33,
#  'full': 34,
#  'gregory_piatetsky': 35,
#  'gregory_piatetsky_kdnugget': 36,
#  'hashtag': 37,
#  'henschen': 38,
#  'higher': 39,
#  'highlight': 40,
#  'influencer': 41,
#  'initial': 42,
#  'interesting': 43,
#  'isolate': 44,
#  'jackson': 45,
#  'jame_kobielus': 46,
#  'jameskobielus': 47,
#  'joab': 48,
#  'kdnugget': 49,
#  'kenneth_cukier': 50,
#  'kirk_bear': 51,
#  'kirkdborne': 52,
#  'klout': 53,
#  'kncukier': 54,
#  'last': 55,
#  'link': 56,
#  'linkedin': 57,
#  'list': 58,
#  'luca': 59,
#  'machlis': 60,
#  'make': 61,
#  'mention': 62,
#  'methodology': 63,
#  'mgualtieri': 64,
#  'michael_cavaretta': 65,
#  'mike_gualtieri': 66,
#  'mjcavaretta': 67,
#  'month': 68,
#  'ms': 69,
#  'nadhanathp': 70,
#  'name': 71,
#  'natasha': 72,
#  'network': 73,
#  'node': 74,
#  'note': 75,
#  'nov': 76,
#  'nstevenluca': 77,
#  'olavsrud': 78,
#  'onalytica': 79,
#  'one': 80,
#  'pagerank': 81,
#  'phil_simon': 82,
#  'philsimon': 83,
#  'pleased': 84,
#  'previous': 85,
#  'put': 86,
#  'rank': 87,
#  'ranking': 88,
#  'ray': 89,
#  'real': 90,
#  'remove': 91,
#  'rwang': 92,
#  'say': 93,
#  'see': 94,
#  'sharon': 95,
#  'show': 96,
#  'steve': 97,
#  'take': 98,
#  'thor': 99,
#  'thorolavsrud': 100,
#  'timo': 101,
#  'timoelliott': 102,
#  'top': 103,
#  'treat': 104,
#  'tweet': 105,
#  'tweeter': 106,
#  'twitter': 107,
#  'twitter_follower': 108,
#  'two': 109,
#  'viktor': 110,
#  'wang': 111,
#  'accelerate': 112,
#  'acquire': 113,
#  'address': 114,
#  'aim': 115,
#  'alliance': 116,
#  'analytic': 117,
#  'announce': 118,
#  'area': 119,
#  'asset': 120,
#  'available': 121,
#  'become': 122,
#  'believe': 123,
#  'business': 124,
#  'capability': 125,
#  'challenge': 126,
#  'client': 127,
#  'company': 128,
#  'compliance': 129,
#  'cost': 130,
#  'create': 131,
#  'critical': 132,
#  'current': 133,
#  'currently': 134,
#  'customer': 135,
#  'da': 136,
#  'derive': 137,
#  'develop': 138,
#  'energy': 139,
#  'enhance': 140,
#  'finance': 141,
#  'financial': 142,
#  'firm': 143,
#  'flexibility': 144,
#  'focus': 145,
#  'formation': 146,
#  'fund': 147,
#  'growth': 148,
#  'healthcare': 149,
#  'help': 150,
#  'important': 151,
#  'improve': 152,
#  'include': 153,
#  'innovate': 154,
#  'innovation': 155,
#  'international': 156,
#  'invest': 157,
#  'investment': 158,
#  'kpmg': 159,
#  'kpmg_capital': 160,
#  'lead': 161,
#  'leader': 162,
#  'management': 163,
#  'many': 164,
#  'member': 165,
#  'new': 166,
#  'new_york': 167,
#  'number': 168,
#  'optimization': 169,
#  'organization': 170,
#  'overwhelming': 171,
#  'partner': 172,
#  'partnership': 173,
#  'plan': 174,
#  'priority': 175,
#  'prnewswire': 176,
#  'productivity': 177,
#  'read': 178,
#  'recruitment': 179,
#  'regulation': 180,
#  'revenue': 181,
#  'risk': 182,
#  'sector': 183,
#  'service': 184,
#  'solution': 185,
#  'solve': 186,
#  'specialize': 187,
#  'strategic': 188,
#  'strategically': 189,
#  'stream': 190,
#  'support': 191,
#  'survey': 192,
#  'talent': 193,
#  'tangible': 194,
#  'technology': 195,
#  'tool': 196,
#  'try': 197,
#  'unlock': 198,
#  'use': 199,
#  'value': 200,
#  'vast_amount': 201,
#  'work': 202,
#  'workforce': 203,
#  'world': 204,
#  'adjunct_faculty': 205,
#  'advance': 206,
#  'advanced': 207,
#  'algorithm': 208,
#  'application': 209,
#  'article': 210,
#  'austria': 211,
#  'awesome': 212,
#  'bad': 213,
#  'bis': 214,
#  'book': 215,
#  'bristol': 216,
#  'bristol_uk': 217,
#  'city': 218,
#  'collaborative': 219,
#  'company_startup_activity': 220,
#  'conference': 221,
#  'connection': 222,
#  'consult': 223,
#  'continue': 224,
#  'contract': 225,
#  'coursera': 226,
#  'data_analysis': 227,
#  'ebay': 228,
#  'eindhoven': 229,
#  'eindhoven_netherland': 230,
#  'engineer': 231,
#  'expansion': 232,
#  'free': 233,
#  'funding': 234,
#  'genetics': 235,
#  'germany': 236,
#  'get': 237,
#  'google': 238,
#  'graph': 239,
#  'hadoop': 240,
#  'hightech': 241,
#  'inc': 242,
#  'initiative': 243,
#  'job': 244,
#  'john_tukey_badmandment': 245,
#  'lab': 246,
#  'learn': 247,
#  'lesson': 248,
#  'longterm': 249,
#  'machine': 250,
#  'million_dollar': 251,
#  'miner': 252,
#  'mining': 253,
#  'mit': 254,
#  'modeler': 255,
#  'multiple': 256,
#  'near': 257,
#  'new_york_ny': 258,
#  'nyu': 259,
#  'oct': 260,
#  'october': 261,
#  'online': 262,
#  'phd': 263,
#  'philadelphia_pa': 264,
#  'plotly': 265,
#  'population': 266,
#  'position': 267,
#  'postdoc': 268,
#  'predictive': 269,
#  'process': 270,
#  'professional': 271,
#  'project': 272,
#  'python': 273,
#  'quantum_physics': 274,
#  'rapidminer': 275,
#  'rebrand': 276,
#  'sage': 277,
#  'san_francisco_can': 278,
#  'san_jose_can': 279,
#  'school': 280,
#  'science': 281,
#  'senseable': 282,
#  'share': 283,
#  'sig': 284,
#  'silicon_valley': 285,
#  'software': 286,
#  'sr': 287,
#  'stanford': 288,
#  'statistics': 289,
#  'step': 290,
#  'strata': 291,
#  'strata_hadoop_world': 292,
#  'stubhub': 293,
#  'study': 294,
#  'system': 295,
#  'teach': 296,
#  'technical': 297,
#  'telecommute': 298,
#  'text': 299,
#  'theory': 300,
#  'top_kdnugget_tweet': 301,
#  'topread': 302,
#  'tu': 303,
#  'uk': 304,
#  'university': 305,
#  'update': 306,
#  'vacancy': 307,
#  'video': 308,
#  'view': 309,
#  'view_news_item': 310,
#  'yangmill': 311,
#  'access': 312,
#  'accumulo': 313,
#  'acquihire': 314,
#  'acquisition': 315,
#  'across': 316,
#  'activity': 317,
#  'acxiom': 318,
#  'adeuoe': 319,
#  'adtsop': 320,
#  'agile': 321,
#  'agroweather': 322,
#  'api': 323,
#  'app': 324,
#  'as': 325,
#  'august': 326,
#  'aunf': 327,
#  'authority': 328,
#  'bank': 329,
#  'banking': 330,
#  'behavioral': 331,
#  'beyond': 332,
#  'bigdataco': 333,
#  'bigdataco_bitly': 334,
#  'bigdataco_buffly': 335,
#  'bitly': 336,
#  'bloombg': 337,
#  'briefs': 338,
#  'buy': 339,
#  'cctv': 340,
#  'choice': 341,
#  'cirro': 342,
#  'click': 343,
#  'climate': 344,
#  'cloud': 345,
#  'cloudbased': 346,
#  'commercialize': 347,
#  'compression': 348,
#  'consulting_firm': 349,
#  'cooladata': 350,
#  'corporation': 351,
#  'custom': 352,
#  'dataasaservice': 353,
#  'database': 354,
#  'db': 355,
#  'des': 356,
#  'developer': 357,
#  'dmregco': 358,
#  'domiknow': 359,
#  'earn': 360,
#  'education': 361,
#  'embedded': 362,
#  'enable': 363,
#  'enterprise': 364,
#  'exploration': 365,
#  'february': 366,
#  'filing': 367,
#  'grijwf': 368,
#  'group': 369,
#  'grzbsn': 370,
#  'guh': 371,
#  'harcourt': 372,
#  'health_care': 373,
#  'hjnrlb': 374,
#  'hlkfi': 375,
#  'houghton': 376,
#  'ien': 377,
#  'iily': 378,
#  'industry': 379,
#  'instantly': 380,
#  'instore': 381,
#  'integration': 382,
#  'intuit': 383,
#  'io': 384,
#  'ipo': 385,
#  'israeli': 386,
#  'jmoj': 387,
#  'july': 388,
#  'kalido': 389,
#  'keen': 390,
#  'king': 391,
#  'kz': 392,
#  'lde': 393,
#  'learning': 394,
#  'level': 395,
#  'logus': 396,
#  'look': 397,
#  'lqi': 398,
#  'lucrative': 399,
#  'maker': 400,
#  'market': 401,
#  'marketing': 402,
#  'mdm': 403,
#  'measurement': 404,
#  'meet': 405,
#  'mifflin': 406,
#  'million': 407,
#  'mine': 408,
#  'mobile': 409,
#  'moinesbased': 410,
#  'mongodb': 411,
#  'monsanto': 412,
#  'nomi': 413,
#  'nosql': 414,
#  'nsadeveloped': 415,
#  'numerify': 416,
#  'nyc': 417,
#  'nytim': 418,
#  'occ': 419,
#  'offer': 420,
#  'onavo': 421,
#  'onmashto': 422,
#  'onthefly': 423,
#  'onwsjcom': 424,
#  'parstream': 425,
#  'people': 426,
#  'personalize': 427,
#  'pivotal': 428,
#  'pj': 429,
#  'placement': 430,
#  'plaid': 431,
#  'platform': 432,
#  'predict': 433,
#  'predilytic': 434,
#  'prism': 435,
#  'private': 436,
#  'provide': 437,
#  'provider': 438,
#  'pursway': 439,
#  'qlpmu': 440,
#  'qyvyf': 441,
#  'raise': 442,
#  'raise_bigdataco': 443,
#  'raise_bigdataco_buffly': 444,
#  'realtime': 445,
#  'realworld': 446,
#  'refinancing': 447,
#  'refresh': 448,
#  'retail': 449,
#  'reveal': 450,
#  'round': 451,
#  'see_latest_hashtag': 452,
#  'sell': 453,
#  'sensor': 454,
#  'september': 455,
#  'series': 456,
#  'shop': 457,
#  'silverback': 458,
#  'simplify': 459,
#  'siqg': 460,
#  'skylab': 461,
#  'smartphone': 462,
#  'so': 463,
#  'source': 464,
#  'sqrrl': 465,
#  'startup': 466,
#  'strength': 467,
#  'sw': 468,
#  'tb': 469,
#  'tcrnch': 470,
#  'tempodb': 471,
#  'transform': 472,
#  'valuation': 473,
#  'vc': 474,
#  'vendor': 475,
#  'warehousing': 476,
#  'we': 477,
#  'wlcce': 478,
#  'xtreme': 479,
#  'xvx': 480,
#  'xzcse': 481,
#  'yhooit': 482,
#  'zgqgo': 483,
#  'academia': 484,
#  'accept': 485,
#  'acceptance': 486,
#  'afternoon': 487,
#  'along': 488,
#  'anmol_rajpurohit': 489,
#  'around': 490,
#  'attend': 491,
#  'attendee': 492,
#  'banquet': 493,
#  'basic': 494,
#  'begin': 495,
#  'berkeley': 496,
#  'brief': 497,
#  'btech': 498,
#  'challenging': 499,
#  'cleanse': 500,
#  'clustering': 501,
#  'coffee_break': 502,
#  'computation': 503,
#  'computer': 504,
#  'concept': 505,
#  'country': 506,
#  'cover': 507,
#  'crowdsource': 508,
#  'day': 509,
#  'deliver': 510,
#  'demonstrate': 511,
#  'describe': 512,
#  'development': 513,
#  'discuss': 514,
#  'dive_deeper': 515,
#  'diverse': 516,
#  'domain': 517,
#  'earlier': 518,
#  'emphasize': 519,
#  'entrepreneur': 520,
#  'etc': 521,
#  'evening': 522,
#  'event': 523,
#  'everyone': 524,
#  'expert': 525,
#  'field': 526,
#  'filter': 527,
#  'final': 528,
#  'finish': 529,
#  'follow': 530,
#  'framework': 531,
#  'franklin': 532,
#  'functional': 533,
#  'garciamolina': 534,
#  'gather': 535,
#  'government': 536,
#  'great': 537,
#  'guest': 538,
#  'heart': 539,
#  'hector': 540,
#  'hive': 541,
#  'hold': 542,
#  'human': 543,
#  'identify': 544,
#  'ieee': 545,
#  'ieee_bigdata': 546,
#  'ieee_international_conference': 547,
#  'immersive_handson': 548,
#  'india': 549,
#  'information_retrieval': 550,
#  'inmemory': 551,
#  'interact': 552,
#  'interactive': 553,
#  'interest': 554,
#  'intern': 555,
#  'issue': 556,
#  'iterative': 557,
#  'judiciously': 558,
#  'keenly_interested': 559,
#  'key': 560,
#  'keynote': 561,
#  'kick': 562,
#  'knowledge': 563,
#  'later': 564,
#  'lecture': 565,
#  'leverage': 566,
#  'mature': 567,
#  'meso': 568,
#  'michael': 569,
#  'opportunity': 570,
#  'organize': 571,
#  'overview': 572,
#  'panel': 573,
#  'panel_discussion': 574,
#  'paper': 575,
#  'papers': 576,
#  'place': 577,
#  'play': 578,
#  'popular': 579,
#  'post': 580,
#  'poster_session': 581,
#  'potential': 582,
#  'practitioner': 583,
#  'privacy': 584,
#  'prof': 585,
#  'program': 586,
#  'promote': 587,
#  'question': 588,
#  'rate': 589,
#  'regular': 590,
#  'remain': 591,
#  'research': 592,
#  'researcher': 593,
#  'roger': 594,
#  'role': 595,
#  'santa_clara': 596,
#  'scalable': 597,
#  'schell': 598,
#  'scientist': 599,
#  'security': 600,
#  'several': 601,
#  'short': 602,
#  'significance': 603,
#  'since': 604,
#  'skill': 605,
#  'socialize': 606,
#  'society': 607,
#  'spark': 608,
#  'speech': 609,
#  'sqllike': 610,
#  'stack': 611,
#  'stanford_university': 612,
#  'start': 613,
#  'state': 614,
#  'subjectmatter': 615,
#  'sunday': 616,
#  'talk': 617,
#  'th': 618,
#  'three': 619,
#  'topic': 620,
#  'tutorial': 621,
#  'uc_berkeley': 622,
#  'ucla': 623,
#  'university_southern_california': 624,
#  'usa': 625,
#  'value_proposition': 626,
#  'variety': 627,
#  'visualization': 628,
#  'web': 629,
#  'well': 630,
#  'whereas': 631,
#  'wide_range': 632,
#  'workshop': 633,
#  'academic': 634,
#  'achieve': 635,
#  'alfr': 636,
#  'already': 637,
#  'alternative': 638,
#  'ambitious': 639,
#  'analytical': 640,
#  'apply': 641,
#  'astrophysicist': 642,
#  'astrophysics': 643,
#  'background': 644,
#  'best': 645,
#  'betty': 646,
#  'bill_melinda_gate': 647,
#  'build': 648,
#  'career': 649,
#  'center': 650,
#  'chair': 651,
#  'characterize': 652,
#  'collaboration': 653,
#  'complex': 654,
#  'contribute': 655,
#  'core': 656,
#  'courant': 657,
#  'culture': 658,
#  'datarich': 659,
#  'director': 660,
#  'discovery': 661,
#  'dollar': 662,
#  'easy': 663,
#  'economics': 664,
#  'ecosystem': 665,
#  'ed': 666,
#  'effort': 667,
#  'engineering': 668,
#  'escience': 669,
#  'establish': 670,
#  'extensible': 671,
#  'faculty': 672,
#  'forward': 673,
#  'found': 674,
#  'foundation': 675,
#  'generation': 676,
#  'goal': 677,
#  'gordon': 678,
#  'harness': 679,
#  'impact': 680,
#  'industrial': 681,
#  'innovative': 682,
#  'institute': 683,
#  'institution': 684,
#  'interaction': 685,
#  'lawrence': 686,
#  'lazowska': 687,
#  'learnable': 688,
#  'massive': 689,
#  'mathematical': 690,
#  'mathematics': 691,
#  'maximize': 692,
#  'meaningful': 693,
#  'meeting': 694,
#  'metric': 695,
#  'mind': 696,
#  'moore_foundation': 697,
#  'move': 698,
#  'multimillion': 699,
#  'national_laboratory': 700,
#  'need': 701,
#  'neural': 702,
#  'nobel_laureate': 703,
#  'noisy': 704,
#  'nurture': 705,
#  'nytime': 706,
#  'office': 707,
#  'ostp': 708,
#  'overcome': 709,
#  'path': 710,
#  'perlmutter': 711,
#  'physics': 712,
#  'policy': 713,
#  'practice': 714,
#  'professor': 715,
#  'recognize': 716,
#  'respective': 717,
#  'retain': 718,
#  'reusable': 719,
#  'reward': 720,
#  'saul': 721,
#  'scientific': 722,
#  'seek': 723,
#  'silver': 724,
#  'sloan': 725,
#  'specific': 726,
#  'spend': 727,
#  'sponsor': 728,
#  'structure': 729,
#  'subject': 730,
#  'substantial': 731,
#  'sustainable': 732,
#  'sustained': 733,
#  'systemic': 734,
#  'tap': 735,
#  'technique': 736,
#  'time': 737,
#  'towards': 738,
#  'translate': 739,
#  'university_california_berkeley': 740,
#  'university_washington': 741,
#  'washington_dc': 742,
#  'white_house': 743,
#  'whose': 744,
#  'yann_lecun': 745,
#  'year': 746,
#  'analyze': 747,
#  'biometric': 748,
#  'biometric_identification': 749,
#  'chance': 750,
#  'characteristic': 751,
#  'classification': 752,
#  'comma_separated': 753,
#  'competition': 754,
#  'contest': 755,
#  'csv': 756,
#  'dataset': 757,
#  'detail': 758,
#  'determine': 759,
#  'dont': 760,
#  'download': 761,
#  'emvic': 762,
#  'equipment': 763,
#  'experience': 764,
#  'eye': 765,
#  'eye_movement': 766,
#  'format': 767,
#  'formula': 768,
#  'good': 769,
#  'however': 770,
#  'identification': 771,
#  'ieee_international': 772,
#  'ijcb': 773,
#  'information': 774,
#  'joint': 775,
#  'march': 776,
#  'may': 777,
#  'model': 778,
#  'official': 779,
#  'organizer': 780,
#  'other': 781,
#  'participant': 782,
#  'participate': 783,
#  'prepare': 784,
#  'ready': 785,
#  'recording': 786,
#  'special': 787,
#  'submission_deadline': 788,
#  'tracking': 789,
#  'verification': 790,
#  'visit': 791,
#  'wwwemvicorg': 792,
#  'able': 793,
#  'addition': 794,
#  'allow': 795,
#  'appbuild': 796,
#  'armonk': 797,
#  'back': 798,
#  'behind': 799,
#  'bring': 800,
#  'buyline': 801,
#  'choose': 802,
#  'class': 803,
#  'clinical': 804,
#  'cloudhosted': 805,
#  'cognitive': 806,
#  'cognitive_computing': 807,
#  'commit': 808,
#  'community': 809,
#  'complement': 810,
#  'connect': 811,
#  'consumer': 812,
#  'content': 813,
#  'conversion': 814,
#  'creative': 815,
#  'datadriven': 816,
#  'decision': 817,
#  'design': 818,
#  'device': 819,
#  'drive': 820,
#  'early': 821,
#  'educational': 822,
#  'emerge': 823,
#  'engagement': 824,
#  'enter': 825,
#  'entrepreneurial': 826,
#  'ever': 827,
#  'exist': 828,
#  'expand': 829,
#  'expect': 830,
#  'expertise': 831,
#  'feature': 832,
#  'first': 833,
#  'fluid': 834,
#  'freelance': 835,
#  'fuel': 836,
#  'health': 837,
#  'hospital': 838,
#  'ibm': 839,
#  'ibm_watson': 840,
#  'inform': 841,
#  'infuse': 842,
#  'insight': 843,
#  'intelligence': 844,
#  'intelligent': 845,
#  'interface': 846,
#  'itinerary': 847,
#  'launch': 848,
#  'life': 849,
#  'marketplace': 850,
#  'marketready': 851,
#  'material': 852,
#  'md': 853,
#  'medical': 854,
#  'nyse': 855,
#  'overall': 856,
#  'part': 857,
#  'personal': 858,
#  'pioneer': 859,
#  'player': 860,
#  'power': 861,
#  'product': 862,
#  'programmer': 863,
#  'programming': 864,
#  'purchase': 865,
#  'range': 866,
#  'resource': 867,
#  'serve': 868,
#  'shared': 869,
#  'shopper': 870,
#  'shopping': 871,
#  'size': 872,
#  'skilled': 873,
#  'sm': 874,
#  'social': 875,
#  'spur': 876,
#  'store': 877,
#  'subject_matter_expert': 878,
#  'supply_chain': 879,
#  'target': 880,
#  'team': 881,
#  'thirdparty': 882,
#  'today': 883,
#  'together': 884,
#  'toolkit': 885,
#  'uncover': 886,
#  'unveil': 887,
#  'user': 888,
#  'venture_capital': 889,
#  'version': 890,
#  'vision': 891,
#  'watson': 892,
#  'watsonpower': 893,
#  'watsonpowered': 894,
#  'welltok': 895,
#  'worldwide': 896,
#  'accurate': 897,
#  'action': 898,
#  'actually': 899,
#  'adrienne': 900,
#  'aeronautics': 901,
#  'afterwards': 902,
#  'age_gender': 903,
#  'alewife': 904,
#  'algorithmic': 905,
#  'allstar': 906,
#  'almost': 907,
#  'although': 908,
#  'among': 909,
#  'another': 910,
#  'anscombe': 911,
#  'answer': 912,
#  'anticipate': 913,
#  'approximate': 914,
#  'architect': 915,
#  'artificial_intelligence': 916,
#  'ask': 917,
#  'aspire': 918,
#  'assoc': 919,
#  'astronautics': 920,
#  'atla': 921,
#  'attempt': 922,
#  'automate': 923,
#  'automated': 924,
#  'automation': 925,
#  'barrier_adoption': 926,
#  'be': 927,
#  'beer': 928,
#  'biggest': 929,
#  'bill': 930,
#  'blossom': 931,
#  'bold': 932,
#  'bonafide': 933,
#  'boston': 934,
#  'box': 935,
#  'bracket': 936,
#  'bullish': 937,
#  'cambridge': 938,
#  'cart': 939,
#  'case': 940,
#  'ceo': 941,
#  'change': 942,
#  'chri': 943,
#  'chris': 944,
#  'chris_lynch': 945,
#  'closer': 946,
#  'coarse': 947,
#  'cochrane': 948,
#  'cofounder': 949,
#  'cofounder_cto': 950,
#  'collection': 951,
#  'compare': 952,
#  'complicated': 953,
#  'compute': 954,
#  'consist': 955,
#  'convenience': 956,
#  'count': 957,
#  'couple': 958,
#  'crosschannel': 959,
#  'csail': 960,
#  'dataxu': 961,
#  'decide': 962,
#  'density': 963,
#  'description': 964,
#  'despite': 965,
#  'difficult': 966,
#  'discussion': 967,
#  'disrupt': 968,
#  'dr': 969,
#  'either': 970,
#  'end': 971,
#  'enduser': 972,
#  'engine': 973,
#  'enough': 974,
#  'entity': 975,
#  'era': 976,
#  'error': 977,
#  'every': 978,
#  'everything': 979,
#  'exact': 980,
#  'example': 981,
#  'excite': 982,
#  'exciting': 983,
#  'exclude': 984,
#  'exclusively': 985,
#  'experiment': 986,
#  'express': 987,
#  'extensively': 988,
#  'face': 989,
#  'fall': 990,
#  'festival': 991,
#  'finally': 992,
#  'firstever': 993,
#  'founder': 994,
#  'frequently': 995,
#  'fully': 996,
#  'garbage_garbage': 997,
#  'give': 998,
#  'gm': 999,
#  ...}

# %%
# gensim corpus
corpus = [token_dict.doc2bow(d) for d in dtm]

# %%
corpus[0][:10]
# Out:
# [(0, 1),
#  (1, 2),
#  (2, 1),
#  (3, 1),
#  (4, 1),
#  (5, 1),
#  (6, 2),
#  (7, 4),
#  (8, 1),
#  (9, 1)]

# %%
# Just if you want a glimpse
# word_counts = [[(token_dict[id], count) for id, count in doc] for doc in corpus]
# word_counts[0]

# %% [markdown]
# #### Building the model

# %% [markdown]
# We're gonna move all the below to a colab notebook to use the GPU, but it can appear on the same page on the website

# %%
from gensim.models.ldamodel import LdaModel

lda_model = LdaModel(corpus, 
                     num_topics=30,
                     id2word=token_dict,
                     alpha='auto',
                     chunksize=200,
                     update_every=1,
                     passes=4,
                     #minimum_probability=.05
                    )

# %%
from pprint import pprint

# %%
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(28,
#   '0.089*"embedding" + 0.054*"gan" + 0.036*"datum" + 0.027*"conference" + '
#   '0.022*"use" + 0.020*"nov" + 0.018*"code" + 0.013*"boxplot" + 0.012*"apr" + '
#   '0.011*"world"'),
#  (27,
#   '0.059*"be" + 0.038*"sep" + 0.036*"oct" + 0.035*"analytic" + 0.031*"summit" '
#   '+ 0.026*"mar" + 0.025*"datum" + 0.023*"kdnugget" + 0.023*"aug" + '
#   '0.022*"jun"'),
#  (25,
#   '0.171*"tco" + 0.048*"df" + 0.024*"chatbot" + 0.021*"cartoon" + '
#   '0.016*"machinelearning" + 0.013*"datascience" + 0.011*"python" + '
#   '0.010*"tweet" + 0.008*"popular_kdnugget_tweet" + '
#   '0.007*"top_engaging_tweet"'),
#  (6,
#   '0.068*"spark" + 0.019*"listing" + 0.013*"film" + 0.009*"loan" + '
#   '0.009*"alexa" + 0.007*"gartner_magic_quadrant" + 0.007*"lightning" + '
#   '0.006*"tuner" + 0.006*"rapidminer" + 0.006*"recode"'),
#  (4,
#   '0.027*"bert" + 0.012*"fig" + 0.012*"series" + 0.011*"paper" + '
#   '0.010*"result" + 0.010*"year" + 0.009*"attention" + 0.009*"na" + '
#   '0.008*"region" + 0.008*"mining"'),
#  (13,
#   '0.051*"pytorch" + 0.018*"book" + 0.010*"blue" + 0.009*"edition" + '
#   '0.009*"click" + 0.009*"julia" + 0.009*"datatable" + 0.008*"domino" + '
#   '0.008*"callback" + 0.008*"lr"'),
#  (0,
#   '0.028*"cnn" + 0.028*"research" + 0.019*"application" + 0.019*"position" + '
#   '0.018*"information" + 0.016*"university" + 0.016*"cv" + 0.015*"faculty" + '
#   '0.011*"department" + 0.011*"text"'),
#  (18,
#   '0.018*"normal_distribution" + 0.015*"startup" + 0.015*"blockchain" + '
#   '0.013*"platform" + 0.010*"investor" + 0.009*"vendor" + 0.009*"company" + '
#   '0.009*"analytic" + 0.008*"plz" + 0.007*"firm"'),
#  (12,
#   '0.047*"plot" + 0.021*"import" + 0.016*"id" + 0.013*"datum" + 0.011*"line" + '
#   '0.011*"return" + 0.010*"function" + 0.009*"let" + 0.008*"dropout" + '
#   '0.008*"def"'),
#  (10,
#   '0.034*"matrix" + 0.027*"instance" + 0.022*"cell" + 0.017*"array" + '
#   '0.016*"linear_regression" + 0.015*"tensor" + 0.014*"max" + 0.013*"return" + '
#   '0.013*"tensorflow" + 0.010*"loop"'),
#  (23,
#   '0.016*"term" + 0.012*"article" + 0.009*"human" + 0.009*"figure" + '
#   '0.007*"context" + 0.007*"minimize" + 0.007*"comment" + 0.006*"however" + '
#   '0.006*"noise" + 0.006*"title"'),
#  (14,
#   '0.037*"value" + 0.020*"datum" + 0.020*"number" + 0.017*"variable" + '
#   '0.013*"mean" + 0.013*"figure" + 0.012*"rate" + 0.012*"show" + '
#   '0.011*"distribution" + 0.010*"use"'),
#  (26,
#   '0.067*"be" + 0.051*"learning" + 0.050*"deep" + 0.048*"image" + '
#   '0.044*"learn" + 0.029*"machine" + 0.021*"layer" + 0.020*"neural_network" + '
#   '0.017*"network" + 0.013*"architecture"'),
#  (2,
#   '0.034*"use" + 0.029*"code" + 0.026*"python" + 0.020*"library" + '
#   '0.014*"create" + 0.013*"run" + 0.013*"text" + 0.011*"project" + '
#   '0.010*"tool" + 0.010*"file"'),
#  (22,
#   '0.173*"datum" + 0.083*"science" + 0.067*"learn" + 0.063*"machine" + '
#   '0.051*"scientist" + 0.021*"learning" + 0.016*"top" + 0.016*"python" + '
#   '0.014*"job" + 0.008*"deep"'),
#  (9,
#   '0.051*"datum" + 0.029*"business" + 0.020*"analytic" + 0.014*"model" + '
#   '0.013*"process" + 0.013*"customer" + 0.012*"use" + 0.009*"need" + '
#   '0.009*"decision" + 0.008*"tool"'),
#  (21,
#   '0.056*"model" + 0.026*"use" + 0.021*"feature" + 0.014*"train" + '
#   '0.013*"training" + 0.012*"learn" + 0.012*"word" + 0.011*"algorithm" + '
#   '0.011*"set" + 0.010*"dataset"'),
#  (16,
#   '0.093*"datum" + 0.020*"big" + 0.017*"technology" + 0.010*"company" + '
#   '0.009*"new" + 0.009*"year" + 0.007*"industry" + 0.007*"cloud" + '
#   '0.006*"platform" + 0.006*"trend"'),
#  (5,
#   '0.024*"science" + 0.019*"research" + 0.018*"learn" + 0.015*"course" + '
#   '0.014*"nlp" + 0.010*"field" + 0.010*"program" + 0.010*"computer" + '
#   '0.010*"topic" + 0.009*"datum"'),
#  (3,
#   '0.013*"datum" + 0.013*"make" + 0.013*"one" + 0.012*"get" + 0.012*"time" + '
#   '0.010*"like" + 0.010*"need" + 0.009*"work" + 0.009*"way" + 0.008*"take"')]

# %%
# Compute Perplexity
print('Perplexity: ', lda_model.log_perplexity(corpus))
# Out:
# Perplexity:  -8.154051796950784

# %%
from gensim.models import CoherenceModel
# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, 
                                     texts=dtm, 
                                     dictionary=token_dict, 
                                     coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('Coherence Score: ', coherence_lda)
# Out:
# Coherence Score:  0.45688426431489676

# %% [markdown]
# Careful, below will take a very long time to run

# %%
# import pyLDAvis
# import pyLDAvis.gensim
import matplotlib.pyplot as plt
# %matplotlib inline
# Visualize the topics
# pyLDAvis.enable_notebook()
# vis = pyLDAvis.gensim.prepare(lda_model, corpus, token_dict)
# vis

# %% [markdown]
# DEV: Need to reduce the common words influencing these topics, stricter tf-idf or other, if we already seem to be doing the best we can in terms of idf then research other potential strategies.

# %%
tfidf = models.TfidfModel(corpus, smartirs='ntc') # feel free to change
# corpus_tfidf = tfidf[corpus]
# for doc in corpus_tfidf:
#     print(doc)

# %% [markdown]
# ## Supervised Topic Modeling

# %% [markdown]
# (predicting tags, using our own custom train/val/test data here)

# %% [markdown]
# #### End tags predicting

# %% [markdown]
# ## Unsupervised Topic Modeling

# %% [markdown]
#  Possible models to consider:
#
#  1. LSA - tf-idf to truncated SVD for dimensionality reduction
#
#  2. 1999, pLSA (Probabilistic Latent Sentiment Analysis) - tf-idf to probabilistic approach, e.g. $P(d,w) = \sum_{t \epsilon T} P(t)P(d|t)P(w|t)$
#
#  3. LDA (Latent Dirichlet Allocation) - e.g. Bayesian pLSA. It can generalize to newly introduced docs (advantage over pLSA). We draw random sample of topic dist $Dir(\alpha)$ and $Dir(\beta)$
#
#
#
# LDA general notation:
#
# $M$ denotes the number of documents
#
# $N$ is number of words in a given document (document $i$ has $N_{i}$ words)
#
# $\alpha$ is the parameter of the Dirichlet prior on the per-document topic distributions
#
# $\beta$ is the parameter of the Dirichlet prior on the per-topic word distribution
#
# $\theta_{i}$ is the topic distribution for document i
#
# $\phi_{k}$ is the word distribution for topic k
#
# $z_{ij}$ is the topic for the j-th word in document i
#
# $w_{ij}$ is the specific word.
#
# https://en.wikipedia.org/wiki/Latent_Dirichlet_allocation
#
#
#
# 4. lda2vec - deep learning approach, more effective for large datasets (we'll use it next time when we have a larger set to work with)

# %% [markdown]
# adbhj

# %% [markdown]
# ### Topic Modeling: ngrams-TFIDF

# %% [markdown]
# ### PLSA, etc?

# %% [markdown]
# ### Dynamic Topic Modeling
